# %%
# !git clone https://github.com/HenriqueSchmitz/mario-the-explorer
# Out:
# Cloning into 'mario-the-explorer'...
# remote: Enumerating objects: 313, done.
# remote: Counting objects: 100% (313/313), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 313 (delta 159), reused 241 (delta 95), pack-reused 0 (from 0)
# Receiving objects: 100% (313/313), 1.18 MiB | 5.67 MiB/s, done.
# Resolving deltas: 100% (159/159), done.

# %%
# !sh ./mario-the-explorer/setup.sh
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.1/123.1 MB 243.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 392.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 102.4 MB/s eta 0:00:00
#   Building wheel for mario-the-explorer (pyproject.toml) ... done
# Importing SuperMarioWorld-Snes-v0
# Imported 1 games

# %%
# !pip install -q stable-baselines3
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 24.6 MB/s eta 0:00:00

# %%
from typing import Optional
from enum import Enum
from logging import Logger

import cv2
import torch
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import KVWriter, Logger as PpoLogger

from mario_the_explorer import (SuperMarioWorldLayeredEmulator, RewardModel, ScreenOverlay, Tile, get_file_logger,
                                tile_absolute_id, TileEncoder, SuperMarioAction, SuperMarioCombo, SuperMarioDiscretizer,
                                prime_policy_for_combo, TileType, SCREEN_COLUMNS, SCREEN_ROWS, TILE_SIZE)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class Direction(Enum):
    LEFT = 0
    RIGHT = 1
    UP = 2
    DOWN = 3

# %%
from re import T
from mario_the_explorer.environment import tiles
class TryThingsRewardModel(RewardModel):
    def __init__(self, new_block_reward = 10.0, action_reward = 1.0, progression_reward = 0.1):
        self._blocks_seen = set()
        self._block_action_counts = {}
        self._block_available_rewards = {}
        self._best_distance_reached = 0
        self._new_block_reward = new_block_reward
        self._action_reward = action_reward
        self._progression_reward = progression_reward
        self.MAX_BLOCK_REWARD = self._get_total_reward_for_block()

    def reset(self) -> None:
        self._blocks_seen = set()
        self._block_action_counts = {}
        self._block_available_rewards = {}
        self._best_distance_reached = 0

    def _get_total_reward_for_block(self, number_of_actions = 10, number_of_directions = 4) -> float:
        total_possible_reward = 0.0
        last_total_possible_reward = -1
        interactions = 0
        while total_possible_reward != last_total_possible_reward:
            last_total_possible_reward = total_possible_reward
            interactions += 1
            total_possible_reward += self._reward_curve(interactions)
        return total_possible_reward * number_of_actions * number_of_directions

    def _reward_curve(self, action_count: int) -> float:
        action_reward = self._action_reward / action_count
        if action_reward < 0.05:
            action_reward = 0.0
        return action_reward

    def get_reward(self,
                   action: list[int],
                   observation: list[list[Tile]],
                   terminated: bool,
                   truncated: bool,
                   info: dict) -> float:
        reward = 0.0
        for row in observation:
            for tile in row:
                tile_id = tile_absolute_id(tile)
                if tile["type"] == TileType.EMPTY:
                    self._block_available_rewards[tile_id] = 0
                    continue
                if tile["type"] == TileType.MARIO:
                    self._block_available_rewards[tile_id] = 0
                    continue
                if tile_id not in self._blocks_seen:
                    self._blocks_seen.add(tile_id)
                    reward += 10.0
                    self._block_available_rewards[tile_id] = self.MAX_BLOCK_REWARD
        tiles_around_mario = self._get_tiles_around_mario(observation)
        for tile_and_direction in tiles_around_mario:
            combo_id = SuperMarioCombo.get_combo_id_from_action(action)
            if combo_id == SuperMarioCombo.DO_NOTHING:
                continue
            interaction_id = (combo_id, tile_and_direction[0], tile_and_direction[1])
            action_reward = 0.0
            if interaction_id not in self._block_action_counts:
                self._block_action_counts[interaction_id] = 0
            self._block_action_counts[interaction_id] += 1
            action_reward = self._reward_curve(self._block_action_counts[interaction_id])
            self._block_available_rewards[tile_and_direction[1]] -= action_reward
            reward += action_reward
        if info["x"] > self._best_distance_reached:
            self._best_distance_reached = info["x"]
            reward += 0.1
        if terminated:
            unique_tiles_visible = set()
            for row in observation:
                for tile in row:
                    unique_tiles_visible.add(tile_absolute_id(tile))
            valid_tiles_visible = len(unique_tiles_visible) - 2
            max_reward_possible = valid_tiles_visible * self.MAX_BLOCK_REWARD
            reward_still_available = 0
            for tile_id in self._block_available_rewards:
                reward_still_available += self._block_available_rewards[tile_id]
            explored_percentage = reward_still_available / max_reward_possible
            reward -= explored_percentage * 20.0
        return reward

    def _get_tiles_around_mario(self, observation: list[list[Tile]]) -> set[tuple[Direction, int]]:
        mario_coordinates = self._find_mario_coordinates(observation)
        blocks_around_mario = set()
        if not mario_coordinates:
            return blocks_around_mario
        for mario_row, mario_col in mario_coordinates:
            if mario_row > 0:
                block_above_mario = observation[mario_row - 1][mario_col]
                if block_above_mario["type"] != TileType.MARIO and block_above_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.UP.name, tile_absolute_id(block_above_mario)))
            if mario_row < len(observation) - 1:
                block_below_mario = observation[mario_row + 1][mario_col]
                if block_below_mario["type"] != TileType.MARIO and block_below_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.DOWN.name, tile_absolute_id(block_below_mario)))
            if mario_col > 0:
                block_left_of_mario = observation[mario_row][mario_col - 1]
                if block_left_of_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.LEFT.name, tile_absolute_id(block_left_of_mario)))
            if mario_col < len(observation[0]) - 1:
                block_right_of_mario = observation[mario_row][mario_col + 1]
                if block_right_of_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.RIGHT.name, tile_absolute_id(block_right_of_mario)))
        return blocks_around_mario


    def _find_mario_coordinates(self, observation: list[list[Tile]]) -> list[tuple[int, int]]:
        mario_coordinates = []
        for row_idx, row in enumerate(observation):
            for col_idx, tile in enumerate(row):
                if tile["type"] == TileType.MARIO:
                    mario_coordinates.append((row_idx, col_idx))
        return mario_coordinates

    def get_potential_map(self, observation: list[list[Tile]]) -> np.ndarray:
        h, w = len(observation), len(observation[0])
        potential_map = np.zeros((h, w), dtype=np.float32)
        for r in range(h):
            for c in range(w):
                t_id = tile_absolute_id(observation[r][c])
                potential_map[r, c] = self._block_available_rewards.get(t_id, 0.0)/self.MAX_BLOCK_REWARD
        return potential_map

# %%
class MarioReshapeWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        # Get the original H, W (14, 16)
        c, h, w = self.observation_space.shape
        # Redefine the space to include a single channel (1, 14, 16)
        self.observation_space = gym.spaces.Box(
            low=0,
            high=255,
            shape=(c+1, h, w),
            dtype=np.float32
        )

    def observation(self, obs):
        reward_model = self.env.unwrapped.reward_model
        heatmap = reward_model.get_potential_map(self.env.unwrapped.observation)
        heatmap = np.expand_dims(heatmap, axis=0)
        screen = np.concat([obs, heatmap], axis=0).astype(np.float32)
        return screen

# %%
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
import torch.nn as nn

class CustomMarioCNN(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 512):
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]

        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Flatten()
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            sample_tensor = torch.as_tensor(observation_space.sample()[None]).float()
            n_flatten = self.cnn(sample_tensor).shape[1]

        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU(),
            nn.Linear(features_dim, features_dim),
            nn.ReLU()
        )

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))

# %%
GRID_COLOR_RGB = (80, 80, 80)

class RewardHeatmapOverlay(ScreenOverlay):
    def __init__(self, reward_model: TryThingsRewardModel):
        self._reward_model = reward_model
        self.img_width = SCREEN_COLUMNS * TILE_SIZE
        self.img_height = SCREEN_ROWS * TILE_SIZE

    def apply(self, original_frame: np.ndarray, observation: Optional[list[list[Tile]]]):
        if observation is None:
            return original_frame
        reward_map = self._reward_model.get_potential_map(observation)
        reward_image = self._get_reward_image(reward_map)
        return np.vstack((original_frame, reward_image))

    def _get_reward_image(self, reward_map):
        matrix_img = np.zeros((self.img_height, self.img_width, 3), dtype=np.uint8)
        matrix_img = self._populate_objects(matrix_img, reward_map)
        matrix_img = self._draw_grid(matrix_img)
        unused_region = np.zeros((self.img_height, self.img_width, 3), dtype=np.uint8)
        return np.hstack((matrix_img, unused_region))

    def _populate_objects(self, matrix_img, reward_map):
        for row in range(SCREEN_ROWS):
            for col in range(SCREEN_COLUMNS):
                tile_available_reward = reward_map[row][col]
                self._draw_tile(matrix_img, col, row, tile_available_reward)
        return matrix_img

    def _draw_tile(self, img, x: int, y: int, tile_available_reward: float) -> None:
        scaled_reward = int(tile_available_reward * 255)
        visually_uniform_grayscale = scaled_reward ** 2.2
        color = (visually_uniform_grayscale, visually_uniform_grayscale, visually_uniform_grayscale)
        x_start = int(x * TILE_SIZE)
        y_start = int(y * TILE_SIZE)
        x_end = x_start + TILE_SIZE - 1
        y_end = y_start + TILE_SIZE - 1
        cv2.rectangle(img, (x_start, y_start), (x_end, y_end), color, -1)

    def _draw_grid(self, img):
        h, w = img.shape[:2]
        for x in range(0, w + 1, TILE_SIZE):
            cv2.line(img, (x, 0), (x, h), GRID_COLOR_RGB, 1)
        for y in range(0, h + 1, TILE_SIZE):
            cv2.line(img, (0, y), (w, y), GRID_COLOR_RGB, 1)
        return img

# %%
RUN_NAME = "padded_larger_policy_network"
LEVEL = "DonutPlains1"
LOG_LEVEL = "INFO"
MAX_STEPS = 2000

# %%
class PpoKvWriter(KVWriter):
    def __init__(self, logger: Logger):
        self._logger = logger

    def write(self, key_values, key_excluded, step=0):
        for key, value in key_values.items():
            self._logger.info(f"Step {step} - {key}: {value}")

    def close(self):
        pass

# %%
logger = get_file_logger(RUN_NAME, LOG_LEVEL)
ppo_logger = PpoLogger(
    folder=None,
    output_formats=[PpoKvWriter(logger)]
)
reward_model = TryThingsRewardModel()
overlay = RewardHeatmapOverlay(reward_model)
base_env = SuperMarioWorldLayeredEmulator(level = LEVEL,
                                          render_mode = "rgb_array",
                                          reward_model = reward_model,
                                          screen_overlay = overlay,
                                          render_debug = True,
                                          render_grid = True,
                                          max_episode_length = MAX_STEPS,
                                          limit_fps_to = 5,
                                          logger = logger)
env = SuperMarioDiscretizer(base_env)
env = MarioReshapeWrapper(env)
# Out:
# 2026-05-07 13:21:57 [INFO] Session log for run padded_larger_policy_network with level [INFO] initialized at: padded_larger_policy_network_20260507_132157.log

# %%
try:
    ppo_env = DummyVecEnv([lambda: env])
    policy_kwargs = dict(
        features_extractor_class=CustomMarioCNN,
        features_extractor_kwargs=dict(features_dim=512),
    )
    model = PPO("CnnPolicy", ppo_env, policy_kwargs=policy_kwargs, verbose=1, learning_rate=0.0003, n_steps=500, device=device)
    model.set_logger(ppo_logger)
    # prime_policy_for_combo(model, SuperMarioCombo.RIGHT_RUN, ppo_env, logger, iterations=1)
    logger.info("Starting training...")
    model.learn(total_timesteps=30000)
    model.save("ppo_mario_test")
except Exception as e:
    logger.error(e)
    raise e
finally:
    env.reset()
# Out:
# Using cpu device
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/ppo/ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 500`, after every 7 untruncated mini-batches, there will be a truncated mini-batch of size 52
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=500 and n_envs=1)
#   warnings.warn(
# 2026-05-07 13:22:04 [INFO] Starting training...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# 2026-05-07 13:22:16 [INFO] Step 500 - time/iterations: 1
# 2026-05-07 13:22:16 [INFO] Step 500 - time/fps: 41
# 2026-05-07 13:22:16 [INFO] Step 500 - time/time_elapsed: 11
# 2026-05-07 13:22:16 [INFO] Step 500 - time/total_timesteps: 500
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/learning_rate: 0.0003
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/entropy_loss: -2.388426956534386
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/policy_gradient_loss: -0.022288464976008983
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/value_loss: 152.6414870738983
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/approx_kl: 0.015041187405586243
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/clip_fraction: 0.19525240431539714
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/loss: 64.95671844482422
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/explained_variance: 0.011504828929901123
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/n_updates: 10
# 2026-05-07 13:22:40 [INFO] Step 1000 - train/clip_range: 0.2
# 2026-05-07 13:22:40 [INFO] Step 1000 - time/iterations: 2
# 2026-05-07 13:22:40 [INFO] Step 1000 - time/fps: 27
# 2026-05-07 13:22:40 [INFO] Step 1000 - time/time_elapsed: 36
# 2026-05-07 13:22:40 [INFO] Step 1000 - time/total_timesteps: 1000
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/learning_rate: 0.0003
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/entropy_loss: -2.384737879037857
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/policy_gradient_loss: -0.008192918958229711
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/value_loss: 603.9511417388916
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/approx_kl: 0.007831329479813576
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/clip_fraction: 0.015579928015358745
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/loss: 326.75506591796875
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/explained_variance: 0.002607583999633789
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/n_updates: 20
# 2026-05-07 13:23:04 [INFO] Step 1500 - train/clip_range: 0.2
# 2026-05-07 13:23:04 [INFO] Step 1500 - time/iterations: 3
# 2026-05-07 13:23:04 [INFO] Step 1500 - time/fps: 24
# 2026-05-07 13:23:04 [INFO] Step 1500 - time/time_elapsed: 60
# 2026-05-07 13:23:04 [INFO] Step 1500 - time/total_timesteps: 1500
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/learning_rate: 0.0003
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/entropy_loss: -2.3716670989990236
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/policy_gradient_loss: -0.008463117505561968
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/value_loss: 410.43439998626707
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/approx_kl: 0.00859760120511055
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/clip_fraction: 0.02028245199471712
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/loss: 157.8101043701172
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/explained_variance: 3.230571746826172e-05
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/n_updates: 30
# 2026-05-07 13:23:29 [INFO] Step 2000 - train/clip_range: 0.2
# 2026-05-07 13:23:29 [INFO] Step 2000 - time/iterations: 4
# 2026-05-07 13:23:29 [INFO] Step 2000 - time/fps: 23
# 2026-05-07 13:23:29 [INFO] Step 2000 - time/time_elapsed: 85
# 2026-05-07 13:23:29 [INFO] Step 2000 - time/total_timesteps: 2000
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/learning_rate: 0.0003
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/entropy_loss: -2.3568193435668947
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/policy_gradient_loss: -0.005825561857636785
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/value_loss: 665.649602508545
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/approx_kl: 0.004877559840679169
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/clip_fraction: 0.025525841489434244
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/loss: 294.1661682128906
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/explained_variance: 0.0
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/n_updates: 40
# 2026-05-07 13:23:54 [INFO] Step 2500 - train/clip_range: 0.2
# 2026-05-07 13:23:54 [INFO] Step 2500 - time/iterations: 5
# 2026-05-07 13:23:54 [INFO] Step 2500 - time/fps: 22
# 2026-05-07 13:23:54 [INFO] Step 2500 - time/time_elapsed: 110
# 2026-05-07 13:23:54 [INFO] Step 2500 - time/total_timesteps: 2500
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/learning_rate: 0.0003
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/entropy_loss: -2.3307192116975783
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/policy_gradient_loss: -0.01646590842756268
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/value_loss: 784.714956665039
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/approx_kl: 0.010931301862001419
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/clip_fraction: 0.09586838972754777
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/loss: 296.1456604003906
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/explained_variance: 0.0
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/n_updates: 50
# 2026-05-07 13:24:18 [INFO] Step 3000 - train/clip_range: 0.2
# 2026-05-07 13:24:18 [INFO] Step 3000 - time/iterations: 6
# 2026-05-07 13:24:18 [INFO] Step 3000 - time/fps: 22
# 2026-05-07 13:24:18 [INFO] Step 3000 - time/time_elapsed: 134
# 2026-05-07 13:24:18 [INFO] Step 3000 - time/total_timesteps: 3000
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/learning_rate: 0.0003
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/entropy_loss: -2.293077191710472
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/policy_gradient_loss: -0.0044059988314984365
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/value_loss: 693.7940895080567
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/approx_kl: 0.010342394933104515
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/clip_fraction: 0.0471304087433964
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/loss: 382.0992126464844
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/explained_variance: 0.0
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/n_updates: 60
# 2026-05-07 13:24:43 [INFO] Step 3500 - train/clip_range: 0.2
# 2026-05-07 13:24:43 [INFO] Step 3500 - time/iterations: 7
# 2026-05-07 13:24:43 [INFO] Step 3500 - time/fps: 21
# 2026-05-07 13:24:43 [INFO] Step 3500 - time/time_elapsed: 159
# 2026-05-07 13:24:43 [INFO] Step 3500 - time/total_timesteps: 3500
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/learning_rate: 0.0003
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/entropy_loss: -2.311953234672546
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/policy_gradient_loss: 0.003447902906918898
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/value_loss: 862.9431030273438
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/approx_kl: 0.006730410270392895
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/clip_fraction: 0.003395432699471712
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/loss: 471.91998291015625
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/explained_variance: 0.0
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/n_updates: 70
# 2026-05-07 13:25:08 [INFO] Step 4000 - train/clip_range: 0.2
# 2026-05-07 13:25:08 [INFO] Step 4000 - time/iterations: 8
# 2026-05-07 13:25:08 [INFO] Step 4000 - time/fps: 21
# 2026-05-07 13:25:08 [INFO] Step 4000 - time/time_elapsed: 184
# 2026-05-07 13:25:08 [INFO] Step 4000 - time/total_timesteps: 4000
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/learning_rate: 0.0003
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/entropy_loss: -2.292155370116234
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/policy_gradient_loss: -0.009961214044597
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/value_loss: 648.0568073272705
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/approx_kl: 0.01034508552402258
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/clip_fraction: 0.05345552903600037
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/loss: 299.56195068359375
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/explained_variance: 0.0
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/n_updates: 80
# 2026-05-07 13:25:35 [INFO] Step 4500 - train/clip_range: 0.2
# 2026-05-07 13:25:35 [INFO] Step 4500 - time/iterations: 9
# 2026-05-07 13:25:35 [INFO] Step 4500 - time/fps: 21
# 2026-05-07 13:25:35 [INFO] Step 4500 - time/time_elapsed: 211
# 2026-05-07 13:25:35 [INFO] Step 4500 - time/total_timesteps: 4500
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/learning_rate: 0.0003
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/entropy_loss: -2.262865075469017
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/policy_gradient_loss: -0.002841076835466083
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/value_loss: 772.478663635254
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/approx_kl: 0.0021019205451011658
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/clip_fraction: 0.0
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/loss: 276.31048583984375
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/explained_variance: 0.0
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/n_updates: 90
# 2026-05-07 13:26:04 [INFO] Step 5000 - train/clip_range: 0.2
# 2026-05-07 13:26:04 [INFO] Step 5000 - time/iterations: 10
# 2026-05-07 13:26:04 [INFO] Step 5000 - time/fps: 20
# 2026-05-07 13:26:04 [INFO] Step 5000 - time/time_elapsed: 240
# 2026-05-07 13:26:04 [INFO] Step 5000 - time/total_timesteps: 5000
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/learning_rate: 0.0003
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/entropy_loss: -2.215295934677124
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/policy_gradient_loss: -0.009802827490011623
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/value_loss: 992.4952415466308
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/approx_kl: 0.011002556420862675
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/clip_fraction: 0.054657452087849376
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/loss: 409.4590148925781
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/explained_variance: 0.0
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/n_updates: 100
# 2026-05-07 13:26:33 [INFO] Step 5500 - train/clip_range: 0.2
# 2026-05-07 13:26:33 [INFO] Step 5500 - time/iterations: 11
# 2026-05-07 13:26:33 [INFO] Step 5500 - time/fps: 20
# 2026-05-07 13:26:33 [INFO] Step 5500 - time/time_elapsed: 269
# 2026-05-07 13:26:33 [INFO] Step 5500 - time/total_timesteps: 5500
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/learning_rate: 0.0003
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/entropy_loss: -2.202145662903786
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/policy_gradient_loss: -0.010785888119062292
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/value_loss: 916.9951881408691
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/approx_kl: 0.013311539776623249
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/clip_fraction: 0.10195312518626451
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/loss: 559.07080078125
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/explained_variance: 0.0
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/n_updates: 110
# 2026-05-07 13:27:03 [INFO] Step 6000 - train/clip_range: 0.2
# 2026-05-07 13:27:03 [INFO] Step 6000 - time/iterations: 12
# 2026-05-07 13:27:03 [INFO] Step 6000 - time/fps: 20
# 2026-05-07 13:27:03 [INFO] Step 6000 - time/time_elapsed: 299
# 2026-05-07 13:27:03 [INFO] Step 6000 - time/total_timesteps: 6000
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/learning_rate: 0.0003
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/entropy_loss: -2.132856410741806
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/policy_gradient_loss: -0.006759983587835449
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/value_loss: 827.8480155944824
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/approx_kl: 0.011714253574609756
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/clip_fraction: 0.1283954325132072
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/loss: 311.38702392578125
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/explained_variance: -1.1920928955078125e-07
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/n_updates: 120
# 2026-05-07 13:27:32 [INFO] Step 6500 - train/clip_range: 0.2
# 2026-05-07 13:27:32 [INFO] Step 6500 - time/iterations: 13
# 2026-05-07 13:27:32 [INFO] Step 6500 - time/fps: 19
# 2026-05-07 13:27:32 [INFO] Step 6500 - time/time_elapsed: 328
# 2026-05-07 13:27:32 [INFO] Step 6500 - time/total_timesteps: 6500
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/learning_rate: 0.0003
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/entropy_loss: -2.129602479934692
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/policy_gradient_loss: -0.003154089767485857
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/value_loss: 1175.6585342407227
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/approx_kl: 0.0028620443772524595
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/clip_fraction: 0.0
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/loss: 508.59942626953125
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/explained_variance: -1.1920928955078125e-07
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/n_updates: 130
# 2026-05-07 13:28:01 [INFO] Step 7000 - train/clip_range: 0.2
# 2026-05-07 13:28:01 [INFO] Step 7000 - time/iterations: 14
# 2026-05-07 13:28:01 [INFO] Step 7000 - time/fps: 19
# 2026-05-07 13:28:01 [INFO] Step 7000 - time/time_elapsed: 357
# 2026-05-07 13:28:01 [INFO] Step 7000 - time/total_timesteps: 7000
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/learning_rate: 0.0003
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/entropy_loss: -2.151254114508629
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/policy_gradient_loss: -0.0006591455619016529
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/value_loss: 1132.5361457824706
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/approx_kl: 0.0002979803248308599
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/clip_fraction: 0.0
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/loss: 557.5343017578125
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/explained_variance: 0.0
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/n_updates: 140
# 2026-05-07 13:28:29 [INFO] Step 7500 - train/clip_range: 0.2
# 2026-05-07 13:28:29 [INFO] Step 7500 - time/iterations: 15
# 2026-05-07 13:28:29 [INFO] Step 7500 - time/fps: 19
# 2026-05-07 13:28:29 [INFO] Step 7500 - time/time_elapsed: 385
# 2026-05-07 13:28:29 [INFO] Step 7500 - time/total_timesteps: 7500
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/learning_rate: 0.0003
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/entropy_loss: -2.092521971464157
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/policy_gradient_loss: -0.0037181197585596237
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/value_loss: 1142.4696426391602
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/approx_kl: 0.028355976566672325
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/clip_fraction: 0.18837139438837766
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/loss: 414.9483642578125
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/explained_variance: 1.1920928955078125e-07
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/n_updates: 150
# 2026-05-07 13:28:56 [INFO] Step 8000 - train/clip_range: 0.2
# 2026-05-07 13:28:56 [INFO] Step 8000 - time/iterations: 16
# 2026-05-07 13:28:56 [INFO] Step 8000 - time/fps: 19
# 2026-05-07 13:28:56 [INFO] Step 8000 - time/time_elapsed: 412
# 2026-05-07 13:28:56 [INFO] Step 8000 - time/total_timesteps: 8000
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/learning_rate: 0.0003
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/entropy_loss: -2.0371533751487734
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/policy_gradient_loss: -0.0006932823293027468
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/value_loss: 1660.4590133666993
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/approx_kl: 0.0007848126697354019
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/clip_fraction: 0.0
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/loss: 1129.139404296875
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/explained_variance: 5.960464477539063e-08
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/n_updates: 160
# 2026-05-07 13:29:23 [INFO] Step 8500 - train/clip_range: 0.2
# 2026-05-07 13:29:23 [INFO] Step 8500 - time/iterations: 17
# 2026-05-07 13:29:23 [INFO] Step 8500 - time/fps: 19
# 2026-05-07 13:29:23 [INFO] Step 8500 - time/time_elapsed: 439
# 2026-05-07 13:29:23 [INFO] Step 8500 - time/total_timesteps: 8500
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/learning_rate: 0.0003
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/entropy_loss: -2.0143167585134507
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/policy_gradient_loss: -0.005416105322365183
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/value_loss: 1410.5976959228515
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/approx_kl: 0.010570143349468708
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/clip_fraction: 0.0
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/loss: 840.164306640625
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/explained_variance: 0.0
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/n_updates: 170
# 2026-05-07 13:29:51 [INFO] Step 9000 - train/clip_range: 0.2
# 2026-05-07 13:29:51 [INFO] Step 9000 - time/iterations: 18
# 2026-05-07 13:29:51 [INFO] Step 9000 - time/fps: 19
# 2026-05-07 13:29:51 [INFO] Step 9000 - time/time_elapsed: 467
# 2026-05-07 13:29:51 [INFO] Step 9000 - time/total_timesteps: 9000
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/learning_rate: 0.0003
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/entropy_loss: -1.9622996777296067
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/policy_gradient_loss: -0.009179019379371312
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/value_loss: 1636.5110733032227
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/approx_kl: 0.01241693738847971
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/clip_fraction: 0.09800180289894342
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/loss: 728.1859130859375
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/explained_variance: 0.0
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/n_updates: 180
# 2026-05-07 13:30:17 [INFO] Step 9500 - train/clip_range: 0.2
# 2026-05-07 13:30:17 [INFO] Step 9500 - time/iterations: 19
# 2026-05-07 13:30:17 [INFO] Step 9500 - time/fps: 19
# 2026-05-07 13:30:17 [INFO] Step 9500 - time/time_elapsed: 493
# 2026-05-07 13:30:17 [INFO] Step 9500 - time/total_timesteps: 9500
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/learning_rate: 0.0003
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/entropy_loss: -1.8961614802479745
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/policy_gradient_loss: -0.0037709672818891705
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/value_loss: 1239.6802894592286
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/approx_kl: 0.01123623177409172
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/clip_fraction: 0.007001201971434057
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/loss: 504.9164733886719
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/explained_variance: 0.0
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/n_updates: 190
# 2026-05-07 13:30:44 [INFO] Step 10000 - train/clip_range: 0.2
# 2026-05-07 13:30:44 [INFO] Step 10000 - time/iterations: 20
# 2026-05-07 13:30:44 [INFO] Step 10000 - time/fps: 19
# 2026-05-07 13:30:44 [INFO] Step 10000 - time/time_elapsed: 520
# 2026-05-07 13:30:44 [INFO] Step 10000 - time/total_timesteps: 10000
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/learning_rate: 0.0003
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/entropy_loss: -1.859538994729519
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/policy_gradient_loss: -0.00996312429469981
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/value_loss: 1428.6237396240235
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/approx_kl: 0.011330815963447094
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/clip_fraction: 0.12327223559841513
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/loss: 722.8679809570312
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/explained_variance: 0.0
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/n_updates: 200
# 2026-05-07 13:31:10 [INFO] Step 10500 - train/clip_range: 0.2
# 2026-05-07 13:31:10 [INFO] Step 10500 - time/iterations: 21
# 2026-05-07 13:31:10 [INFO] Step 10500 - time/fps: 19
# 2026-05-07 13:31:10 [INFO] Step 10500 - time/time_elapsed: 546
# 2026-05-07 13:31:10 [INFO] Step 10500 - time/total_timesteps: 10500
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/learning_rate: 0.0003
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/entropy_loss: -1.9177521169185638
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/policy_gradient_loss: -0.013690333283739165
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/value_loss: 1404.8072570800782
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/approx_kl: 0.017086494714021683
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/clip_fraction: 0.21551983249373735
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/loss: 720.36865234375
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/explained_variance: 5.960464477539063e-08
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/n_updates: 210
# 2026-05-07 13:31:39 [INFO] Step 11000 - train/clip_range: 0.2
# 2026-05-07 13:31:39 [INFO] Step 11000 - time/iterations: 22
# 2026-05-07 13:31:39 [INFO] Step 11000 - time/fps: 19
# 2026-05-07 13:31:39 [INFO] Step 11000 - time/time_elapsed: 574
# 2026-05-07 13:31:39 [INFO] Step 11000 - time/total_timesteps: 11000
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/learning_rate: 0.0003
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/entropy_loss: -1.8169442102313043
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/policy_gradient_loss: -0.00968951515496883
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/value_loss: 1230.5800231933595
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/approx_kl: 0.010755492374300957
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/clip_fraction: 0.10036057718098164
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/loss: 484.1360168457031
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/explained_variance: 0.0
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/n_updates: 220
# 2026-05-07 13:32:07 [INFO] Step 11500 - train/clip_range: 0.2
# 2026-05-07 13:32:07 [INFO] Step 11500 - time/iterations: 23
# 2026-05-07 13:32:07 [INFO] Step 11500 - time/fps: 19
# 2026-05-07 13:32:07 [INFO] Step 11500 - time/time_elapsed: 602
# 2026-05-07 13:32:07 [INFO] Step 11500 - time/total_timesteps: 11500
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/learning_rate: 0.0003
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/entropy_loss: -1.8504300177097321
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/policy_gradient_loss: -0.003689102990028914
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/value_loss: 1235.5020225524902
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/approx_kl: 0.019655264914035797
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/clip_fraction: 0.09854266834445298
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/loss: 615.1593017578125
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/explained_variance: 0.0
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/n_updates: 230
# 2026-05-07 13:32:35 [INFO] Step 12000 - train/clip_range: 0.2
# 2026-05-07 13:32:35 [INFO] Step 12000 - time/iterations: 24
# 2026-05-07 13:32:35 [INFO] Step 12000 - time/fps: 18
# 2026-05-07 13:32:35 [INFO] Step 12000 - time/time_elapsed: 631
# 2026-05-07 13:32:35 [INFO] Step 12000 - time/total_timesteps: 12000
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/learning_rate: 0.0003
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/entropy_loss: -1.7712849915027618
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/policy_gradient_loss: 0.003155275388417067
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/value_loss: 1728.4174743652343
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/approx_kl: 0.015082556754350662
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/clip_fraction: 0.08188100983388721
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/loss: 883.359375
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/explained_variance: 0.0
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/n_updates: 240
# 2026-05-07 13:33:04 [INFO] Step 12500 - train/clip_range: 0.2
# 2026-05-07 13:33:04 [INFO] Step 12500 - time/iterations: 25
# 2026-05-07 13:33:04 [INFO] Step 12500 - time/fps: 18
# 2026-05-07 13:33:04 [INFO] Step 12500 - time/time_elapsed: 660
# 2026-05-07 13:33:04 [INFO] Step 12500 - time/total_timesteps: 12500
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/learning_rate: 0.0003
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/entropy_loss: -1.7416756018996238
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/policy_gradient_loss: -0.008770402559093782
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/value_loss: 1273.6156425476074
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/approx_kl: 0.009489694610238075
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/clip_fraction: 0.05078125009313226
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/loss: 639.2828369140625
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/explained_variance: 0.0
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/n_updates: 250
# 2026-05-07 13:33:32 [INFO] Step 13000 - train/clip_range: 0.2
# 2026-05-07 13:33:32 [INFO] Step 13000 - time/iterations: 26
# 2026-05-07 13:33:32 [INFO] Step 13000 - time/fps: 18
# 2026-05-07 13:33:32 [INFO] Step 13000 - time/time_elapsed: 688
# 2026-05-07 13:33:32 [INFO] Step 13000 - time/total_timesteps: 13000
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/learning_rate: 0.0003
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/entropy_loss: -1.724892121553421
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/policy_gradient_loss: -0.004513819653402607
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/value_loss: 1484.2795440673829
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/approx_kl: 0.0031874505802989006
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/clip_fraction: 0.0
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/loss: 721.8175659179688
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/explained_variance: 1.1920928955078125e-07
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/n_updates: 260
# 2026-05-07 13:34:01 [INFO] Step 13500 - train/clip_range: 0.2
# 2026-05-07 13:34:01 [INFO] Step 13500 - time/iterations: 27
# 2026-05-07 13:34:01 [INFO] Step 13500 - time/fps: 18
# 2026-05-07 13:34:01 [INFO] Step 13500 - time/time_elapsed: 717
# 2026-05-07 13:34:01 [INFO] Step 13500 - time/total_timesteps: 13500
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/learning_rate: 0.0003
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/entropy_loss: -1.631891268491745
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/policy_gradient_loss: -0.006334149425674696
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/value_loss: 1280.0901718139648
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/approx_kl: 0.007036881521344185
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/clip_fraction: 0.1322716347873211
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/loss: 582.6883544921875
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/explained_variance: 0.0
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/n_updates: 270
# 2026-05-07 13:34:30 [INFO] Step 14000 - train/clip_range: 0.2
# 2026-05-07 13:34:30 [INFO] Step 14000 - time/iterations: 28
# 2026-05-07 13:34:30 [INFO] Step 14000 - time/fps: 18
# 2026-05-07 13:34:30 [INFO] Step 14000 - time/time_elapsed: 746
# 2026-05-07 13:34:30 [INFO] Step 14000 - time/total_timesteps: 14000
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/learning_rate: 0.0003
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/entropy_loss: -1.5867644131183625
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/policy_gradient_loss: -0.012348338903393596
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/value_loss: 1508.2414489746093
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/approx_kl: 0.016698844730854034
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/clip_fraction: 0.14869290897622706
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/loss: 842.1190795898438
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/explained_variance: 0.0
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/n_updates: 280
# 2026-05-07 13:34:59 [INFO] Step 14500 - train/clip_range: 0.2
# 2026-05-07 13:34:59 [INFO] Step 14500 - time/iterations: 29
# 2026-05-07 13:34:59 [INFO] Step 14500 - time/fps: 18
# 2026-05-07 13:34:59 [INFO] Step 14500 - time/time_elapsed: 775
# 2026-05-07 13:34:59 [INFO] Step 14500 - time/total_timesteps: 14500
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/learning_rate: 0.0003
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/entropy_loss: -1.476044374704361
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/policy_gradient_loss: -0.0024901076656533407
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/value_loss: 1900.7613983154297
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/approx_kl: 0.012381508015096188
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/clip_fraction: 0.03766526449471712
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/loss: 1165.7091064453125
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/explained_variance: -1.1920928955078125e-07
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/n_updates: 290
# 2026-05-07 13:35:28 [INFO] Step 15000 - train/clip_range: 0.2
# 2026-05-07 13:35:28 [INFO] Step 15000 - time/iterations: 30
# 2026-05-07 13:35:28 [INFO] Step 15000 - time/fps: 18
# 2026-05-07 13:35:28 [INFO] Step 15000 - time/time_elapsed: 804
# 2026-05-07 13:35:28 [INFO] Step 15000 - time/total_timesteps: 15000
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/learning_rate: 0.0003
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/entropy_loss: -1.4279715567827225
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/policy_gradient_loss: 0.0007000131299719214
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/value_loss: 1520.6205169677735
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/approx_kl: 0.00025154402828775346
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/clip_fraction: 0.0
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/loss: 800.6743774414062
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/explained_variance: 0.0
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/n_updates: 300
# 2026-05-07 13:35:57 [INFO] Step 15500 - train/clip_range: 0.2
# 2026-05-07 13:35:57 [INFO] Step 15500 - time/iterations: 31
# 2026-05-07 13:35:57 [INFO] Step 15500 - time/fps: 18
# 2026-05-07 13:35:57 [INFO] Step 15500 - time/time_elapsed: 832
# 2026-05-07 13:35:57 [INFO] Step 15500 - time/total_timesteps: 15500
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/learning_rate: 0.0003
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/entropy_loss: -1.3767409846186638
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/policy_gradient_loss: -0.004866909806514741
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/value_loss: 1530.6130432128907
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/approx_kl: 0.0025148941203951836
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/clip_fraction: 0.022400841396301985
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/loss: 638.2577514648438
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/explained_variance: -1.1920928955078125e-07
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/n_updates: 310
# 2026-05-07 13:36:25 [INFO] Step 16000 - train/clip_range: 0.2
# 2026-05-07 13:36:25 [INFO] Step 16000 - time/iterations: 32
# 2026-05-07 13:36:25 [INFO] Step 16000 - time/fps: 18
# 2026-05-07 13:36:25 [INFO] Step 16000 - time/time_elapsed: 861
# 2026-05-07 13:36:25 [INFO] Step 16000 - time/total_timesteps: 16000
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/learning_rate: 0.0003
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/entropy_loss: -1.425377368927002
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/policy_gradient_loss: -0.003400481232529273
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/value_loss: 1302.4565406799315
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/approx_kl: 0.008822480216622353
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/clip_fraction: 0.0960787262301892
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/loss: 826.9156494140625
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/explained_variance: 0.0
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/n_updates: 320
# 2026-05-07 13:36:53 [INFO] Step 16500 - train/clip_range: 0.2
# 2026-05-07 13:36:53 [INFO] Step 16500 - time/iterations: 33
# 2026-05-07 13:36:53 [INFO] Step 16500 - time/fps: 18
# 2026-05-07 13:36:53 [INFO] Step 16500 - time/time_elapsed: 889
# 2026-05-07 13:36:53 [INFO] Step 16500 - time/total_timesteps: 16500
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/learning_rate: 0.0003
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/entropy_loss: -1.405195266008377
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/policy_gradient_loss: -0.0062508982126018965
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/value_loss: 1442.0313339233398
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/approx_kl: 0.009952154941856861
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/clip_fraction: 0.06179387052543461
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/loss: 717.3126220703125
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/explained_variance: 0.0
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/n_updates: 330
# 2026-05-07 13:37:23 [INFO] Step 17000 - train/clip_range: 0.2
# 2026-05-07 13:37:23 [INFO] Step 17000 - time/iterations: 34
# 2026-05-07 13:37:23 [INFO] Step 17000 - time/fps: 18
# 2026-05-07 13:37:23 [INFO] Step 17000 - time/time_elapsed: 918
# 2026-05-07 13:37:23 [INFO] Step 17000 - time/total_timesteps: 17000
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/learning_rate: 0.0003
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/entropy_loss: -1.259361207485199
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/policy_gradient_loss: -0.012169046889175661
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/value_loss: 1738.818910217285
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/approx_kl: 0.005633500404655933
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/clip_fraction: 0.07824519253335893
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/loss: 638.0672607421875
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/explained_variance: 0.0
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/n_updates: 340
# 2026-05-07 13:37:51 [INFO] Step 17500 - train/clip_range: 0.2
# 2026-05-07 13:37:51 [INFO] Step 17500 - time/iterations: 35
# 2026-05-07 13:37:51 [INFO] Step 17500 - time/fps: 18
# 2026-05-07 13:37:51 [INFO] Step 17500 - time/time_elapsed: 947
# 2026-05-07 13:37:51 [INFO] Step 17500 - time/total_timesteps: 17500
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/learning_rate: 0.0003
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/entropy_loss: -1.324559934437275
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/policy_gradient_loss: -0.0018051927134365541
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/value_loss: 1479.7131942749024
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/approx_kl: 0.005730877164751291
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/clip_fraction: 0.05591947140637785
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/loss: 761.9096069335938
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/explained_variance: 0.0
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/n_updates: 350
# 2026-05-07 13:38:21 [INFO] Step 18000 - train/clip_range: 0.2
# 2026-05-07 13:38:21 [INFO] Step 18000 - time/iterations: 36
# 2026-05-07 13:38:21 [INFO] Step 18000 - time/fps: 18
# 2026-05-07 13:38:21 [INFO] Step 18000 - time/time_elapsed: 977
# 2026-05-07 13:38:21 [INFO] Step 18000 - time/total_timesteps: 18000
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/learning_rate: 0.0003
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/entropy_loss: -1.370880125463009
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/policy_gradient_loss: -0.001253485234337859
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/value_loss: 1382.7914924621582
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/approx_kl: 0.006289512384682894
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/clip_fraction: 0.018885216489434243
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/loss: 579.3331909179688
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/explained_variance: 0.0
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/n_updates: 360
# 2026-05-07 13:38:51 [INFO] Step 18500 - train/clip_range: 0.2
# 2026-05-07 13:38:51 [INFO] Step 18500 - time/iterations: 37
# 2026-05-07 13:38:51 [INFO] Step 18500 - time/fps: 18
# 2026-05-07 13:38:51 [INFO] Step 18500 - time/time_elapsed: 1007
# 2026-05-07 13:38:51 [INFO] Step 18500 - time/total_timesteps: 18500
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/learning_rate: 0.0003
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/entropy_loss: -1.4806591331958772
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/policy_gradient_loss: -0.005934172122942982
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/value_loss: 1731.7847732543946
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/approx_kl: 0.005945210345089436
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/clip_fraction: 0.030829327134415507
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/loss: 878.7147827148438
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/explained_variance: 0.0
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/n_updates: 370
# 2026-05-07 13:39:20 [INFO] Step 19000 - train/clip_range: 0.2
# 2026-05-07 13:39:20 [INFO] Step 19000 - time/iterations: 38
# 2026-05-07 13:39:20 [INFO] Step 19000 - time/fps: 18
# 2026-05-07 13:39:20 [INFO] Step 19000 - time/time_elapsed: 1036
# 2026-05-07 13:39:20 [INFO] Step 19000 - time/total_timesteps: 19000
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/learning_rate: 0.0003
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/entropy_loss: -1.4545499861240387
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/policy_gradient_loss: 0.0016822488978505135
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/value_loss: 1999.6860733032227
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/approx_kl: 0.004260281100869179
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/clip_fraction: 0.038807091466151175
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/loss: 966.0623168945312
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/explained_variance: 5.960464477539063e-08
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/n_updates: 380
# 2026-05-07 13:39:50 [INFO] Step 19500 - train/clip_range: 0.2
# 2026-05-07 13:39:50 [INFO] Step 19500 - time/iterations: 39
# 2026-05-07 13:39:50 [INFO] Step 19500 - time/fps: 18
# 2026-05-07 13:39:50 [INFO] Step 19500 - time/time_elapsed: 1066
# 2026-05-07 13:39:50 [INFO] Step 19500 - time/total_timesteps: 19500
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/learning_rate: 0.0003
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/entropy_loss: -1.5480381011962892
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/policy_gradient_loss: -0.009333063469239278
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/value_loss: 1838.8665733337402
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/approx_kl: 0.010645009577274323
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/clip_fraction: 0.06730769244022668
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/loss: 865.6937255859375
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/explained_variance: 0.0
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/n_updates: 390
# 2026-05-07 13:40:20 [INFO] Step 20000 - train/clip_range: 0.2
# 2026-05-07 13:40:20 [INFO] Step 20000 - time/iterations: 40
# 2026-05-07 13:40:20 [INFO] Step 20000 - time/fps: 18
# 2026-05-07 13:40:20 [INFO] Step 20000 - time/time_elapsed: 1096
# 2026-05-07 13:40:20 [INFO] Step 20000 - time/total_timesteps: 20000
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/learning_rate: 0.0003
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/entropy_loss: -1.584793496131897
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/policy_gradient_loss: -0.0016302116548104096
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/value_loss: 1633.5669174194336
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/approx_kl: 0.00778393866494298
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/clip_fraction: 0.03360877428203821
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/loss: 695.076416015625
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/explained_variance: 0.0
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/n_updates: 400
# 2026-05-07 13:40:50 [INFO] Step 20500 - train/clip_range: 0.2
# 2026-05-07 13:40:50 [INFO] Step 20500 - time/iterations: 41
# 2026-05-07 13:40:50 [INFO] Step 20500 - time/fps: 18
# 2026-05-07 13:40:50 [INFO] Step 20500 - time/time_elapsed: 1126
# 2026-05-07 13:40:50 [INFO] Step 20500 - time/total_timesteps: 20500
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/learning_rate: 0.0003
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/entropy_loss: -1.4114317163825034
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/policy_gradient_loss: -0.007396275494829752
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/value_loss: 1773.0354263305665
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/approx_kl: 0.022269655019044876
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/clip_fraction: 0.21900540883652866
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/loss: 960.3299560546875
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/explained_variance: -1.1920928955078125e-07
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/n_updates: 410
# 2026-05-07 13:41:19 [INFO] Step 21000 - train/clip_range: 0.2
# 2026-05-07 13:41:19 [INFO] Step 21000 - time/iterations: 42
# 2026-05-07 13:41:19 [INFO] Step 21000 - time/fps: 18
# 2026-05-07 13:41:19 [INFO] Step 21000 - time/time_elapsed: 1155
# 2026-05-07 13:41:19 [INFO] Step 21000 - time/total_timesteps: 21000
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/learning_rate: 0.0003
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/entropy_loss: -1.2363327354192735
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/policy_gradient_loss: -0.011780786037707002
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/value_loss: 1832.9137283325194
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/approx_kl: 0.010304529219865799
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/clip_fraction: 0.1327073319815099
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/loss: 1131.6044921875
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/explained_variance: 0.0
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/n_updates: 420
# 2026-05-07 13:41:48 [INFO] Step 21500 - train/clip_range: 0.2
# 2026-05-07 13:41:48 [INFO] Step 21500 - time/iterations: 43
# 2026-05-07 13:41:48 [INFO] Step 21500 - time/fps: 18
# 2026-05-07 13:41:48 [INFO] Step 21500 - time/time_elapsed: 1184
# 2026-05-07 13:41:48 [INFO] Step 21500 - time/total_timesteps: 21500
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/learning_rate: 0.0003
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/entropy_loss: -1.2762262344360351
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/policy_gradient_loss: -0.005400670957169495
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/value_loss: 1986.753874206543
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/approx_kl: 0.0076178936287760735
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/clip_fraction: 0.04837740396615118
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/loss: 778.5640258789062
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/explained_variance: 0.0
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/n_updates: 430
# 2026-05-07 13:42:17 [INFO] Step 22000 - train/clip_range: 0.2
# 2026-05-07 13:42:17 [INFO] Step 22000 - time/iterations: 44
# 2026-05-07 13:42:17 [INFO] Step 22000 - time/fps: 18
# 2026-05-07 13:42:17 [INFO] Step 22000 - time/time_elapsed: 1213
# 2026-05-07 13:42:17 [INFO] Step 22000 - time/total_timesteps: 22000
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/learning_rate: 0.0003
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/entropy_loss: -1.2172005206346512
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/policy_gradient_loss: -0.0013348904300073627
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/value_loss: 1396.69806060791
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/approx_kl: 0.007943568751215935
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/clip_fraction: 0.04679987996350974
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/loss: 440.58642578125
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/explained_variance: 0.0
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/n_updates: 440
# 2026-05-07 13:42:47 [INFO] Step 22500 - train/clip_range: 0.2
# 2026-05-07 13:42:47 [INFO] Step 22500 - time/iterations: 45
# 2026-05-07 13:42:47 [INFO] Step 22500 - time/fps: 18
# 2026-05-07 13:42:47 [INFO] Step 22500 - time/time_elapsed: 1242
# 2026-05-07 13:42:47 [INFO] Step 22500 - time/total_timesteps: 22500
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/learning_rate: 0.0003
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/entropy_loss: -1.2505844727158546
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/policy_gradient_loss: -0.0005251143535133451
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/value_loss: 1871.6915817260742
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/approx_kl: 0.002286948263645172
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/clip_fraction: 0.07665264438837767
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/loss: 794.0402221679688
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/explained_variance: -1.1920928955078125e-07
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/n_updates: 450
# 2026-05-07 13:43:16 [INFO] Step 23000 - train/clip_range: 0.2
# 2026-05-07 13:43:16 [INFO] Step 23000 - time/iterations: 46
# 2026-05-07 13:43:16 [INFO] Step 23000 - time/fps: 18
# 2026-05-07 13:43:16 [INFO] Step 23000 - time/time_elapsed: 1272
# 2026-05-07 13:43:16 [INFO] Step 23000 - time/total_timesteps: 23000
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/learning_rate: 0.0003
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/entropy_loss: -1.2159937009215356
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/policy_gradient_loss: -0.0030144199525238948
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/value_loss: 1911.2646896362305
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/approx_kl: 0.003219122067093849
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/clip_fraction: 0.021514423214830457
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/loss: 671.7723999023438
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/explained_variance: 0.0
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/n_updates: 460
# 2026-05-07 13:43:46 [INFO] Step 23500 - train/clip_range: 0.2
# 2026-05-07 13:43:46 [INFO] Step 23500 - time/iterations: 47
# 2026-05-07 13:43:46 [INFO] Step 23500 - time/fps: 18
# 2026-05-07 13:43:46 [INFO] Step 23500 - time/time_elapsed: 1301
# 2026-05-07 13:43:46 [INFO] Step 23500 - time/total_timesteps: 23500
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/learning_rate: 0.0003
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/entropy_loss: -1.2124409571290016
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/policy_gradient_loss: -0.003836145571222005
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/value_loss: 1750.9555252075195
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/approx_kl: 0.00738639198243618
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/clip_fraction: 0.06859975983388722
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/loss: 815.0145263671875
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/explained_variance: 0.0
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/n_updates: 470
# 2026-05-07 13:44:15 [INFO] Step 24000 - train/clip_range: 0.2
# 2026-05-07 13:44:15 [INFO] Step 24000 - time/iterations: 48
# 2026-05-07 13:44:15 [INFO] Step 24000 - time/fps: 18
# 2026-05-07 13:44:15 [INFO] Step 24000 - time/time_elapsed: 1331
# 2026-05-07 13:44:15 [INFO] Step 24000 - time/total_timesteps: 24000
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/learning_rate: 0.0003
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/entropy_loss: -1.1259054407477378
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/policy_gradient_loss: -0.0022951223567361013
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/value_loss: 2002.2524780273438
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/approx_kl: 0.002608297858387232
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/clip_fraction: 0.03529146641958505
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/loss: 821.5252075195312
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/explained_variance: -1.1920928955078125e-07
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/n_updates: 480
# 2026-05-07 13:44:45 [INFO] Step 24500 - train/clip_range: 0.2
# 2026-05-07 13:44:45 [INFO] Step 24500 - time/iterations: 49
# 2026-05-07 13:44:45 [INFO] Step 24500 - time/fps: 17
# 2026-05-07 13:44:45 [INFO] Step 24500 - time/time_elapsed: 1361
# 2026-05-07 13:44:45 [INFO] Step 24500 - time/total_timesteps: 24500
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/learning_rate: 0.0003
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/entropy_loss: -1.2311374932527541
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/policy_gradient_loss: -0.0058096549608308125
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/value_loss: 1600.5284240722656
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/approx_kl: 0.009866179898381233
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/clip_fraction: 0.08000300517305732
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/loss: 813.9801635742188
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/explained_variance: 0.0
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/n_updates: 490
# 2026-05-07 13:45:15 [INFO] Step 25000 - train/clip_range: 0.2
# 2026-05-07 13:45:15 [INFO] Step 25000 - time/iterations: 50
# 2026-05-07 13:45:15 [INFO] Step 25000 - time/fps: 17
# 2026-05-07 13:45:15 [INFO] Step 25000 - time/time_elapsed: 1391
# 2026-05-07 13:45:15 [INFO] Step 25000 - time/total_timesteps: 25000
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/learning_rate: 0.0003
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/entropy_loss: -1.2965971544384955
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/policy_gradient_loss: -0.0024388107402046446
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/value_loss: 1878.7056396484375
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/approx_kl: 0.004500450566411018
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/clip_fraction: 0.016361177992075683
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/loss: 868.35009765625
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/explained_variance: 0.0
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/n_updates: 500
# 2026-05-07 13:45:45 [INFO] Step 25500 - train/clip_range: 0.2
# 2026-05-07 13:45:45 [INFO] Step 25500 - time/iterations: 51
# 2026-05-07 13:45:45 [INFO] Step 25500 - time/fps: 17
# 2026-05-07 13:45:45 [INFO] Step 25500 - time/time_elapsed: 1421
# 2026-05-07 13:45:45 [INFO] Step 25500 - time/total_timesteps: 25500
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/learning_rate: 0.0003
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/entropy_loss: -1.1886662393808365
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/policy_gradient_loss: -0.002959510204379967
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/value_loss: 1636.3818344116212
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/approx_kl: 0.010781869292259216
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/clip_fraction: 0.052148437686264516
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/loss: 793.4612426757812
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/explained_variance: 1.7881393432617188e-07
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/n_updates: 510
# 2026-05-07 13:46:14 [INFO] Step 26000 - train/clip_range: 0.2
# 2026-05-07 13:46:14 [INFO] Step 26000 - time/iterations: 52
# 2026-05-07 13:46:14 [INFO] Step 26000 - time/fps: 17
# 2026-05-07 13:46:14 [INFO] Step 26000 - time/time_elapsed: 1450
# 2026-05-07 13:46:14 [INFO] Step 26000 - time/total_timesteps: 26000
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/learning_rate: 0.0003
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/entropy_loss: -1.0551165483891964
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/policy_gradient_loss: -0.0028584060590219453
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/value_loss: 1562.348063659668
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/approx_kl: 0.011070390231907368
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/clip_fraction: 0.04804687516298145
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/loss: 662.5072021484375
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/explained_variance: 0.0
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/n_updates: 520
# 2026-05-07 13:46:44 [INFO] Step 26500 - train/clip_range: 0.2
# 2026-05-07 13:46:44 [INFO] Step 26500 - time/iterations: 53
# 2026-05-07 13:46:44 [INFO] Step 26500 - time/fps: 17
# 2026-05-07 13:46:44 [INFO] Step 26500 - time/time_elapsed: 1480
# 2026-05-07 13:46:44 [INFO] Step 26500 - time/total_timesteps: 26500
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/learning_rate: 0.0003
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/entropy_loss: -0.9486737720668316
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/policy_gradient_loss: -0.00025013006343215237
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/value_loss: 1717.2322494506836
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/approx_kl: 0.00028839928563684225
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/clip_fraction: 0.0
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/loss: 1128.0286865234375
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/explained_variance: 1.1920928955078125e-07
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/n_updates: 530
# 2026-05-07 13:47:13 [INFO] Step 27000 - train/clip_range: 0.2
# 2026-05-07 13:47:13 [INFO] Step 27000 - time/iterations: 54
# 2026-05-07 13:47:13 [INFO] Step 27000 - time/fps: 17
# 2026-05-07 13:47:13 [INFO] Step 27000 - time/time_elapsed: 1509
# 2026-05-07 13:47:13 [INFO] Step 27000 - time/total_timesteps: 27000
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/learning_rate: 0.0003
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/entropy_loss: -1.109535998851061
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/policy_gradient_loss: -0.011247715429635718
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/value_loss: 2143.5046005249023
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/approx_kl: 0.006130656693130732
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/clip_fraction: 0.1262169474735856
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/loss: 1136.5947265625
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/explained_variance: 0.0
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/n_updates: 540
# 2026-05-07 13:47:43 [INFO] Step 27500 - train/clip_range: 0.2
# 2026-05-07 13:47:43 [INFO] Step 27500 - time/iterations: 55
# 2026-05-07 13:47:43 [INFO] Step 27500 - time/fps: 17
# 2026-05-07 13:47:43 [INFO] Step 27500 - time/time_elapsed: 1539
# 2026-05-07 13:47:43 [INFO] Step 27500 - time/total_timesteps: 27500
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/learning_rate: 0.0003
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/entropy_loss: -1.03260013833642
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/policy_gradient_loss: -0.004967646628210786
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/value_loss: 2045.0076171875
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/approx_kl: 0.00482225464656949
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/clip_fraction: 0.05638521660584957
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/loss: 1019.755615234375
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/explained_variance: 0.0
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/n_updates: 550
# 2026-05-07 13:48:12 [INFO] Step 28000 - train/clip_range: 0.2
# 2026-05-07 13:48:12 [INFO] Step 28000 - time/iterations: 56
# 2026-05-07 13:48:12 [INFO] Step 28000 - time/fps: 17
# 2026-05-07 13:48:12 [INFO] Step 28000 - time/time_elapsed: 1568
# 2026-05-07 13:48:12 [INFO] Step 28000 - time/total_timesteps: 28000
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/learning_rate: 0.0003
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/entropy_loss: -0.9988965660333633
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/policy_gradient_loss: -0.0023764513025525957
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/value_loss: 1716.66485748291
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/approx_kl: 0.0019224121933802962
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/clip_fraction: 0.008293269248679281
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/loss: 765.5359497070312
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/explained_variance: 0.0
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/n_updates: 560
# 2026-05-07 13:48:41 [INFO] Step 28500 - train/clip_range: 0.2
# 2026-05-07 13:48:41 [INFO] Step 28500 - time/iterations: 57
# 2026-05-07 13:48:41 [INFO] Step 28500 - time/fps: 17
# 2026-05-07 13:48:41 [INFO] Step 28500 - time/time_elapsed: 1597
# 2026-05-07 13:48:41 [INFO] Step 28500 - time/total_timesteps: 28500
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/learning_rate: 0.0003
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/entropy_loss: -1.0020503520965576
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/policy_gradient_loss: -0.001795525067723247
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/value_loss: 1670.7861495971679
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/approx_kl: 0.0019287444883957505
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/clip_fraction: 0.002373798098415136
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/loss: 720.920654296875
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/explained_variance: 0.0
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/n_updates: 570
# 2026-05-07 13:49:11 [INFO] Step 29000 - train/clip_range: 0.2
# 2026-05-07 13:49:11 [INFO] Step 29000 - time/iterations: 58
# 2026-05-07 13:49:11 [INFO] Step 29000 - time/fps: 17
# 2026-05-07 13:49:11 [INFO] Step 29000 - time/time_elapsed: 1627
# 2026-05-07 13:49:11 [INFO] Step 29000 - time/total_timesteps: 29000
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/learning_rate: 0.0003
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/entropy_loss: -1.0117887139320374
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/policy_gradient_loss: -0.004879589743359248
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/value_loss: 1857.5971740722657
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/approx_kl: 0.004305445123463869
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/clip_fraction: 0.03734975985717028
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/loss: 1029.152099609375
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/explained_variance: -1.1920928955078125e-07
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/n_updates: 580
# 2026-05-07 13:49:40 [INFO] Step 29500 - train/clip_range: 0.2
# 2026-05-07 13:49:40 [INFO] Step 29500 - time/iterations: 59
# 2026-05-07 13:49:40 [INFO] Step 29500 - time/fps: 17
# 2026-05-07 13:49:40 [INFO] Step 29500 - time/time_elapsed: 1656
# 2026-05-07 13:49:40 [INFO] Step 29500 - time/total_timesteps: 29500
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/learning_rate: 0.0003
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/entropy_loss: -0.9671295948326588
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/policy_gradient_loss: -0.001610048285965604
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/value_loss: 2118.5826278686523
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/approx_kl: 0.012237822636961937
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/clip_fraction: 0.03287259638309479
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/loss: 940.1245727539062
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/explained_variance: 0.0
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/n_updates: 590
# 2026-05-07 13:50:10 [INFO] Step 30000 - train/clip_range: 0.2
# 2026-05-07 13:50:10 [INFO] Step 30000 - time/iterations: 60
# 2026-05-07 13:50:10 [INFO] Step 30000 - time/fps: 17
# 2026-05-07 13:50:10 [INFO] Step 30000 - time/time_elapsed: 1686
# 2026-05-07 13:50:10 [INFO] Step 30000 - time/total_timesteps: 30000

# %%
from gymnasium.wrappers import RecordVideo

try:
    env.env.env.limit_fps_to = None
    video_env = RecordVideo(env, video_folder="./", name_prefix=f"trial-{RUN_NAME}", episode_trigger=lambda x: True)
    obs, info = video_env.reset()
    done = False
    step_count = 0
    while not done:
        env.render()
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = video_env.step(action)
        step_count += 1
        if step_count % 1000 == 0:
            logger.info(f"Step: {step_count}")
        done = terminated or truncated
        if done:
            logger.info(f"Terminated: {terminated}")
            logger.info(f"Truncated: {truncated}")
except Exception as e:
    logger.error(e)
    raise e
finally:
    video_env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /content folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 2026-05-07 13:50:38 [INFO] Step: 1000
# 2026-05-07 13:50:40 [INFO] Terminated: True
# 2026-05-07 13:50:40 [INFO] Truncated: False
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
try:
    env.env.env.limit_fps_to = 5
    ppo_env = DummyVecEnv([lambda: env])
    policy_kwargs = dict(
        features_extractor_class=CustomMarioCNN,
        features_extractor_kwargs=dict(features_dim=512),
    )
    model = PPO("CnnPolicy", ppo_env, policy_kwargs=policy_kwargs, verbose=1, learning_rate=0.0003, n_steps=2000, device=device)
    model.set_logger(ppo_logger)
    # prime_policy_for_combo(model, SuperMarioCombo.RIGHT_RUN, ppo_env, logger, iterations=1)
    logger.info("Starting training...")
    model.learn(total_timesteps=500000)
    model.save("ppo_mario_trained")
except Exception as e:
    logger.error(e)
    raise e
finally:
    env.reset()
# Out:
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/ppo/ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2000`, after every 31 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2000 and n_envs=1)
#   warnings.warn(
# Using cpu device
# 2026-05-07 13:50:43 [INFO] Starting training...
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/learning_rate: 0.0003
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/entropy_loss: -0.90427016466856
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/policy_gradient_loss: -0.0024802133564662656
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/value_loss: 1852.4980911254884
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/approx_kl: 0.0023090741597115993
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/clip_fraction: 0.0035456730984151363
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/loss: 887.1220092773438
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/explained_variance: -1.1920928955078125e-07
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/n_updates: 600
# 2026-05-07 13:51:33 [INFO] Step 2000 - train/clip_range: 0.2
# 2026-05-07 13:51:33 [INFO] Step 2000 - time/iterations: 1
# 2026-05-07 13:51:33 [INFO] Step 2000 - time/fps: 40
# 2026-05-07 13:51:33 [INFO] Step 2000 - time/time_elapsed: 49
# 2026-05-07 13:51:33 [INFO] Step 2000 - time/total_timesteps: 2000
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/learning_rate: 0.0003
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/entropy_loss: -2.3885920107364655
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/policy_gradient_loss: -0.01183853551192442
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/value_loss: 87.32736033797264
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/approx_kl: 0.010551181621849537
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/clip_fraction: 0.1314453125
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/loss: 30.060142517089844
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/explained_variance: 0.008506834506988525
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/n_updates: 10
# 2026-05-07 13:53:03 [INFO] Step 4000 - train/clip_range: 0.2
# 2026-05-07 13:53:03 [INFO] Step 4000 - time/iterations: 2
# 2026-05-07 13:53:03 [INFO] Step 4000 - time/fps: 28
# 2026-05-07 13:53:03 [INFO] Step 4000 - time/time_elapsed: 140
# 2026-05-07 13:53:03 [INFO] Step 4000 - time/total_timesteps: 4000
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/learning_rate: 0.0003
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/entropy_loss: -2.382062553614378
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/policy_gradient_loss: -0.008388493170787114
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/value_loss: 261.1890938282013
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/approx_kl: 0.0111235361546278
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/clip_fraction: 0.038525390625
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/loss: 137.6373291015625
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/explained_variance: 0.04077804088592529
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/n_updates: 20
# 2026-05-07 13:54:35 [INFO] Step 6000 - train/clip_range: 0.2
# 2026-05-07 13:54:35 [INFO] Step 6000 - time/iterations: 3
# 2026-05-07 13:54:35 [INFO] Step 6000 - time/fps: 25
# 2026-05-07 13:54:35 [INFO] Step 6000 - time/time_elapsed: 232
# 2026-05-07 13:54:35 [INFO] Step 6000 - time/total_timesteps: 6000
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/learning_rate: 0.0003
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/entropy_loss: -2.35301024466753
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/policy_gradient_loss: -0.007168273627758026
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/value_loss: 505.09901275634763
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/approx_kl: 0.008922548964619637
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/clip_fraction: 0.0203125
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/loss: 94.39109802246094
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/explained_variance: 0.05920445919036865
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/n_updates: 30
# 2026-05-07 13:56:15 [INFO] Step 8000 - train/clip_range: 0.2
# 2026-05-07 13:56:15 [INFO] Step 8000 - time/iterations: 4
# 2026-05-07 13:56:15 [INFO] Step 8000 - time/fps: 24
# 2026-05-07 13:56:15 [INFO] Step 8000 - time/time_elapsed: 332
# 2026-05-07 13:56:15 [INFO] Step 8000 - time/total_timesteps: 8000
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/learning_rate: 0.0003
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/entropy_loss: -2.3266083747148514
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/policy_gradient_loss: -0.000369633779337164
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/value_loss: 586.5584070205689
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/approx_kl: 0.004640418570488691
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/clip_fraction: 0.041162109375
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/loss: 166.06527709960938
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/explained_variance: 0.024217665195465088
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/n_updates: 40
# 2026-05-07 13:57:56 [INFO] Step 10000 - train/clip_range: 0.2
# 2026-05-07 13:57:56 [INFO] Step 10000 - time/iterations: 5
# 2026-05-07 13:57:56 [INFO] Step 10000 - time/fps: 23
# 2026-05-07 13:57:56 [INFO] Step 10000 - time/time_elapsed: 432
# 2026-05-07 13:57:56 [INFO] Step 10000 - time/total_timesteps: 10000
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/learning_rate: 0.0003
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/entropy_loss: -2.304990957677364
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/policy_gradient_loss: -0.003807247749500675
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/value_loss: 769.7020589828492
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/approx_kl: 0.005234468728303909
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/clip_fraction: 0.022216796875
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/loss: 151.6514129638672
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/explained_variance: 0.21483033895492554
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/n_updates: 50
# 2026-05-07 13:59:31 [INFO] Step 12000 - train/clip_range: 0.2
# 2026-05-07 13:59:31 [INFO] Step 12000 - time/iterations: 6
# 2026-05-07 13:59:31 [INFO] Step 12000 - time/fps: 22
# 2026-05-07 13:59:31 [INFO] Step 12000 - time/time_elapsed: 527
# 2026-05-07 13:59:31 [INFO] Step 12000 - time/total_timesteps: 12000
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/learning_rate: 0.0003
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/entropy_loss: -2.2757038064301014
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/policy_gradient_loss: -0.004078880620363634
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/value_loss: 840.1660241127014
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/approx_kl: 0.005989846773445606
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/clip_fraction: 0.032568359375
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/loss: 440.7017517089844
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/explained_variance: 0.2659459114074707
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/n_updates: 60
# 2026-05-07 14:01:06 [INFO] Step 14000 - train/clip_range: 0.2
# 2026-05-07 14:01:06 [INFO] Step 14000 - time/iterations: 7
# 2026-05-07 14:01:06 [INFO] Step 14000 - time/fps: 22
# 2026-05-07 14:01:06 [INFO] Step 14000 - time/time_elapsed: 622
# 2026-05-07 14:01:06 [INFO] Step 14000 - time/total_timesteps: 14000
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/learning_rate: 0.0003
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/entropy_loss: -2.2470514468848704
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/policy_gradient_loss: -0.005771324435045244
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/value_loss: 845.2368395805358
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/approx_kl: 0.0094057098031044
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/clip_fraction: 0.041552734375
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/loss: 368.9251403808594
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/explained_variance: 0.24554920196533203
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/n_updates: 70
# 2026-05-07 14:02:42 [INFO] Step 16000 - train/clip_range: 0.2
# 2026-05-07 14:02:42 [INFO] Step 16000 - time/iterations: 8
# 2026-05-07 14:02:42 [INFO] Step 16000 - time/fps: 22
# 2026-05-07 14:02:42 [INFO] Step 16000 - time/time_elapsed: 719
# 2026-05-07 14:02:42 [INFO] Step 16000 - time/total_timesteps: 16000
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/learning_rate: 0.0003
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/entropy_loss: -2.17155032902956
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/policy_gradient_loss: -0.004277326303417794
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/value_loss: 1024.3584630966186
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/approx_kl: 0.01319853961467743
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/clip_fraction: 0.08232421875
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/loss: 545.2340087890625
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/explained_variance: 0.20801860094070435
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/n_updates: 80
# 2026-05-07 14:04:20 [INFO] Step 18000 - train/clip_range: 0.2
# 2026-05-07 14:04:20 [INFO] Step 18000 - time/iterations: 9
# 2026-05-07 14:04:20 [INFO] Step 18000 - time/fps: 22
# 2026-05-07 14:04:20 [INFO] Step 18000 - time/time_elapsed: 816
# 2026-05-07 14:04:20 [INFO] Step 18000 - time/total_timesteps: 18000
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/learning_rate: 0.0003
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/entropy_loss: -2.140734614431858
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/policy_gradient_loss: -0.004750600804982241
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/value_loss: 1131.460314178467
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/approx_kl: 0.009640147909522057
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/clip_fraction: 0.02431640625
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/loss: 391.02764892578125
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/explained_variance: 0.1973954439163208
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/n_updates: 90
# 2026-05-07 14:05:58 [INFO] Step 20000 - train/clip_range: 0.2
# 2026-05-07 14:05:58 [INFO] Step 20000 - time/iterations: 10
# 2026-05-07 14:05:58 [INFO] Step 20000 - time/fps: 21
# 2026-05-07 14:05:58 [INFO] Step 20000 - time/time_elapsed: 914
# 2026-05-07 14:05:58 [INFO] Step 20000 - time/total_timesteps: 20000
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/learning_rate: 0.0003
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/entropy_loss: -2.1385093182325363
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/policy_gradient_loss: -0.0008987517154309899
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/value_loss: 1128.1498863220215
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/approx_kl: 0.008453650400042534
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/clip_fraction: 0.032470703125
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/loss: 688.5032348632812
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/explained_variance: 0.25712114572525024
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/n_updates: 100
# 2026-05-07 14:07:32 [INFO] Step 22000 - train/clip_range: 0.2
# 2026-05-07 14:07:32 [INFO] Step 22000 - time/iterations: 11
# 2026-05-07 14:07:32 [INFO] Step 22000 - time/fps: 21
# 2026-05-07 14:07:32 [INFO] Step 22000 - time/time_elapsed: 1008
# 2026-05-07 14:07:32 [INFO] Step 22000 - time/total_timesteps: 22000
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/learning_rate: 0.0003
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/entropy_loss: -2.1315683744847775
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/policy_gradient_loss: -0.005971542093902826
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/value_loss: 1088.2374795913697
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/approx_kl: 0.012633273378014565
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/clip_fraction: 0.059130859375
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/loss: 831.8525390625
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/explained_variance: 0.3657901883125305
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/n_updates: 110
# 2026-05-07 14:09:02 [INFO] Step 24000 - train/clip_range: 0.2
# 2026-05-07 14:09:02 [INFO] Step 24000 - time/iterations: 12
# 2026-05-07 14:09:02 [INFO] Step 24000 - time/fps: 21
# 2026-05-07 14:09:02 [INFO] Step 24000 - time/time_elapsed: 1099
# 2026-05-07 14:09:02 [INFO] Step 24000 - time/total_timesteps: 24000
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/learning_rate: 0.0003
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/entropy_loss: -2.1109353065490724
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/policy_gradient_loss: -0.0030934144830098375
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/value_loss: 1072.6467018127441
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/approx_kl: 0.007978100329637527
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/clip_fraction: 0.033056640625
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/loss: 343.78369140625
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/explained_variance: 0.4004558324813843
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/n_updates: 120
# 2026-05-07 14:10:33 [INFO] Step 26000 - train/clip_range: 0.2
# 2026-05-07 14:10:33 [INFO] Step 26000 - time/iterations: 13
# 2026-05-07 14:10:33 [INFO] Step 26000 - time/fps: 21
# 2026-05-07 14:10:33 [INFO] Step 26000 - time/time_elapsed: 1189
# 2026-05-07 14:10:33 [INFO] Step 26000 - time/total_timesteps: 26000
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/learning_rate: 0.0003
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/entropy_loss: -2.0586989879608155
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/policy_gradient_loss: -0.003828130847250577
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/value_loss: 1154.0156435012818
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/approx_kl: 0.01137535274028778
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/clip_fraction: 0.044140625
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/loss: 561.14599609375
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/explained_variance: 0.3050294518470764
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/n_updates: 130
# 2026-05-07 14:11:58 [INFO] Step 28000 - train/clip_range: 0.2
# 2026-05-07 14:11:58 [INFO] Step 28000 - time/iterations: 14
# 2026-05-07 14:11:58 [INFO] Step 28000 - time/fps: 21
# 2026-05-07 14:11:58 [INFO] Step 28000 - time/time_elapsed: 1275
# 2026-05-07 14:11:58 [INFO] Step 28000 - time/total_timesteps: 28000
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/learning_rate: 0.0003
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/entropy_loss: -2.044554074108601
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/policy_gradient_loss: -0.005064577770099277
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/value_loss: 996.2104244232178
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/approx_kl: 0.014187649823725224
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/clip_fraction: 0.124755859375
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/loss: 273.9773864746094
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/explained_variance: 0.4968944191932678
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/n_updates: 140
# 2026-05-07 14:13:24 [INFO] Step 30000 - train/clip_range: 0.2
# 2026-05-07 14:13:24 [INFO] Step 30000 - time/iterations: 15
# 2026-05-07 14:13:24 [INFO] Step 30000 - time/fps: 22
# 2026-05-07 14:13:24 [INFO] Step 30000 - time/time_elapsed: 1361
# 2026-05-07 14:13:24 [INFO] Step 30000 - time/total_timesteps: 30000
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/learning_rate: 0.0003
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/entropy_loss: -2.059523593634367
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/policy_gradient_loss: -0.0036195161621435544
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/value_loss: 984.7793339729309
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/approx_kl: 0.007038973271846771
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/clip_fraction: 0.07236328125
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/loss: 349.923583984375
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/explained_variance: 0.5263402462005615
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/n_updates: 150
# 2026-05-07 14:14:55 [INFO] Step 32000 - train/clip_range: 0.2
# 2026-05-07 14:14:55 [INFO] Step 32000 - time/iterations: 16
# 2026-05-07 14:14:55 [INFO] Step 32000 - time/fps: 22
# 2026-05-07 14:14:55 [INFO] Step 32000 - time/time_elapsed: 1452
# 2026-05-07 14:14:55 [INFO] Step 32000 - time/total_timesteps: 32000
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/learning_rate: 0.0003
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/entropy_loss: -2.0775576382875443
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/policy_gradient_loss: -0.007352005103166448
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/value_loss: 896.722802734375
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/approx_kl: 0.013332435861229897
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/clip_fraction: 0.0939453125
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/loss: 304.05230712890625
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/explained_variance: 0.5750026702880859
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/n_updates: 160
# 2026-05-07 14:16:30 [INFO] Step 34000 - train/clip_range: 0.2
# 2026-05-07 14:16:30 [INFO] Step 34000 - time/iterations: 17
# 2026-05-07 14:16:30 [INFO] Step 34000 - time/fps: 21
# 2026-05-07 14:16:30 [INFO] Step 34000 - time/time_elapsed: 1547
# 2026-05-07 14:16:30 [INFO] Step 34000 - time/total_timesteps: 34000
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/learning_rate: 0.0003
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/entropy_loss: -2.0522905990481375
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/policy_gradient_loss: -0.009052109114418273
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/value_loss: 1057.7473992347718
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/approx_kl: 0.013641316443681717
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/clip_fraction: 0.106396484375
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/loss: 864.5198364257812
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/explained_variance: 0.4970129132270813
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/n_updates: 170
# 2026-05-07 14:18:08 [INFO] Step 36000 - train/clip_range: 0.2
# 2026-05-07 14:18:08 [INFO] Step 36000 - time/iterations: 18
# 2026-05-07 14:18:08 [INFO] Step 36000 - time/fps: 21
# 2026-05-07 14:18:08 [INFO] Step 36000 - time/time_elapsed: 1644
# 2026-05-07 14:18:08 [INFO] Step 36000 - time/total_timesteps: 36000
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/learning_rate: 0.0003
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/entropy_loss: -2.035131412744522
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/policy_gradient_loss: -0.004400979886122513
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/value_loss: 1266.8772562026977
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/approx_kl: 0.005824658088386059
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/clip_fraction: 0.0490234375
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/loss: 910.6920166015625
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/explained_variance: 0.4597688317298889
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/n_updates: 180
# 2026-05-07 14:19:44 [INFO] Step 38000 - train/clip_range: 0.2
# 2026-05-07 14:19:44 [INFO] Step 38000 - time/iterations: 19
# 2026-05-07 14:19:44 [INFO] Step 38000 - time/fps: 21
# 2026-05-07 14:19:44 [INFO] Step 38000 - time/time_elapsed: 1740
# 2026-05-07 14:19:44 [INFO] Step 38000 - time/total_timesteps: 38000
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/learning_rate: 0.0003
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/entropy_loss: -2.0095502845942974
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/policy_gradient_loss: -0.005233581374341156
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/value_loss: 1233.796005821228
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/approx_kl: 0.01013349462300539
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/clip_fraction: 0.12294921875
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/loss: 528.5169677734375
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/explained_variance: 0.4208958148956299
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/n_updates: 190
# 2026-05-07 14:21:20 [INFO] Step 40000 - train/clip_range: 0.2
# 2026-05-07 14:21:20 [INFO] Step 40000 - time/iterations: 20
# 2026-05-07 14:21:20 [INFO] Step 40000 - time/fps: 21
# 2026-05-07 14:21:20 [INFO] Step 40000 - time/time_elapsed: 1836
# 2026-05-07 14:21:20 [INFO] Step 40000 - time/total_timesteps: 40000
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/learning_rate: 0.0003
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/entropy_loss: -2.012586772441864
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/policy_gradient_loss: -0.0014120976462436373
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/value_loss: 1219.5358946800231
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/approx_kl: 0.011013364419341087
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/clip_fraction: 0.048193359375
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/loss: 392.2120666503906
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/explained_variance: 0.5526512861251831
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/n_updates: 200
# 2026-05-07 14:22:55 [INFO] Step 42000 - train/clip_range: 0.2
# 2026-05-07 14:22:55 [INFO] Step 42000 - time/iterations: 21
# 2026-05-07 14:22:55 [INFO] Step 42000 - time/fps: 21
# 2026-05-07 14:22:55 [INFO] Step 42000 - time/time_elapsed: 1932
# 2026-05-07 14:22:55 [INFO] Step 42000 - time/total_timesteps: 42000
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/learning_rate: 0.0003
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/entropy_loss: -1.9682949624955655
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/policy_gradient_loss: -0.0022326792270177974
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/value_loss: 1289.4894882202148
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/approx_kl: 0.011920582503080368
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/clip_fraction: 0.099072265625
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/loss: 447.0413818359375
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/explained_variance: 0.39348524808883667
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/n_updates: 210
# 2026-05-07 14:24:32 [INFO] Step 44000 - train/clip_range: 0.2
# 2026-05-07 14:24:32 [INFO] Step 44000 - time/iterations: 22
# 2026-05-07 14:24:32 [INFO] Step 44000 - time/fps: 21
# 2026-05-07 14:24:32 [INFO] Step 44000 - time/time_elapsed: 2029
# 2026-05-07 14:24:32 [INFO] Step 44000 - time/total_timesteps: 44000
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/learning_rate: 0.0003
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/entropy_loss: -1.9531156916171313
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/policy_gradient_loss: -0.0029580371105112136
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/value_loss: 1296.287643814087
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/approx_kl: 0.007341176271438599
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/clip_fraction: 0.06279296875
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/loss: 947.810546875
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/explained_variance: 0.42771488428115845
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/n_updates: 220
# 2026-05-07 14:26:13 [INFO] Step 46000 - train/clip_range: 0.2
# 2026-05-07 14:26:13 [INFO] Step 46000 - time/iterations: 23
# 2026-05-07 14:26:13 [INFO] Step 46000 - time/fps: 21
# 2026-05-07 14:26:13 [INFO] Step 46000 - time/time_elapsed: 2129
# 2026-05-07 14:26:13 [INFO] Step 46000 - time/total_timesteps: 46000
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/learning_rate: 0.0003
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/entropy_loss: -1.9041027251631022
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/policy_gradient_loss: -0.004925388529954944
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/value_loss: 1294.2946199417115
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/approx_kl: 0.009784966707229614
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/clip_fraction: 0.05390625
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/loss: 1076.153564453125
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/explained_variance: 0.5835428237915039
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/n_updates: 230
# 2026-05-07 14:27:50 [INFO] Step 48000 - train/clip_range: 0.2
# 2026-05-07 14:27:50 [INFO] Step 48000 - time/iterations: 24
# 2026-05-07 14:27:50 [INFO] Step 48000 - time/fps: 21
# 2026-05-07 14:27:50 [INFO] Step 48000 - time/time_elapsed: 2226
# 2026-05-07 14:27:50 [INFO] Step 48000 - time/total_timesteps: 48000
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/learning_rate: 0.0003
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/entropy_loss: -1.885382330045104
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/policy_gradient_loss: -0.003732545334787574
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/value_loss: 1487.5808843612672
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/approx_kl: 0.008035702630877495
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/clip_fraction: 0.04013671875
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/loss: 520.9290161132812
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/explained_variance: 0.4540339708328247
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/n_updates: 240
# 2026-05-07 14:29:27 [INFO] Step 50000 - train/clip_range: 0.2
# 2026-05-07 14:29:27 [INFO] Step 50000 - time/iterations: 25
# 2026-05-07 14:29:27 [INFO] Step 50000 - time/fps: 21
# 2026-05-07 14:29:27 [INFO] Step 50000 - time/time_elapsed: 2324
# 2026-05-07 14:29:27 [INFO] Step 50000 - time/total_timesteps: 50000
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/learning_rate: 0.0003
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/entropy_loss: -1.8258848655968904
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/policy_gradient_loss: -0.006792517856956693
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/value_loss: 1195.729604434967
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/approx_kl: 0.01369332242757082
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/clip_fraction: 0.094091796875
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/loss: 299.7784118652344
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/explained_variance: 0.5948410034179688
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/n_updates: 250
# 2026-05-07 14:31:07 [INFO] Step 52000 - train/clip_range: 0.2
# 2026-05-07 14:31:07 [INFO] Step 52000 - time/iterations: 26
# 2026-05-07 14:31:07 [INFO] Step 52000 - time/fps: 21
# 2026-05-07 14:31:07 [INFO] Step 52000 - time/time_elapsed: 2424
# 2026-05-07 14:31:07 [INFO] Step 52000 - time/total_timesteps: 52000
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/learning_rate: 0.0003
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/entropy_loss: -1.796687589585781
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/policy_gradient_loss: -0.0026931140084343495
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/value_loss: 1278.7997985839843
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/approx_kl: 0.012851259671151638
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/clip_fraction: 0.094775390625
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/loss: 394.5390319824219
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/explained_variance: 0.5405358076095581
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/n_updates: 260
# 2026-05-07 14:32:45 [INFO] Step 54000 - train/clip_range: 0.2
# 2026-05-07 14:32:45 [INFO] Step 54000 - time/iterations: 27
# 2026-05-07 14:32:45 [INFO] Step 54000 - time/fps: 21
# 2026-05-07 14:32:45 [INFO] Step 54000 - time/time_elapsed: 2522
# 2026-05-07 14:32:45 [INFO] Step 54000 - time/total_timesteps: 54000
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/learning_rate: 0.0003
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/entropy_loss: -1.7825981453061104
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/policy_gradient_loss: -0.007040983834303916
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/value_loss: 1091.4362174987793
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/approx_kl: 0.013606819324195385
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/clip_fraction: 0.09765625
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/loss: 661.5634155273438
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/explained_variance: 0.6308944821357727
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/n_updates: 270
# 2026-05-07 14:34:24 [INFO] Step 56000 - train/clip_range: 0.2
# 2026-05-07 14:34:24 [INFO] Step 56000 - time/iterations: 28
# 2026-05-07 14:34:24 [INFO] Step 56000 - time/fps: 21
# 2026-05-07 14:34:24 [INFO] Step 56000 - time/time_elapsed: 2620
# 2026-05-07 14:34:24 [INFO] Step 56000 - time/total_timesteps: 56000
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/learning_rate: 0.0003
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/entropy_loss: -1.8082508124411105
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/policy_gradient_loss: -0.008157774287974462
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/value_loss: 1371.7448656082154
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/approx_kl: 0.01260614674538374
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/clip_fraction: 0.12216796875
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/loss: 412.08074951171875
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/explained_variance: 0.5725873708724976
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/n_updates: 280
# 2026-05-07 14:36:03 [INFO] Step 58000 - train/clip_range: 0.2
# 2026-05-07 14:36:03 [INFO] Step 58000 - time/iterations: 29
# 2026-05-07 14:36:03 [INFO] Step 58000 - time/fps: 21
# 2026-05-07 14:36:03 [INFO] Step 58000 - time/time_elapsed: 2720
# 2026-05-07 14:36:03 [INFO] Step 58000 - time/total_timesteps: 58000
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/learning_rate: 0.0003
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/entropy_loss: -1.7853018529713154
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/policy_gradient_loss: -0.0019533743732608857
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/value_loss: 1239.508300590515
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/approx_kl: 0.00781990960240364
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/clip_fraction: 0.051611328125
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/loss: 576.7512817382812
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/explained_variance: 0.5728869438171387
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/n_updates: 290
# 2026-05-07 14:37:46 [INFO] Step 60000 - train/clip_range: 0.2
# 2026-05-07 14:37:46 [INFO] Step 60000 - time/iterations: 30
# 2026-05-07 14:37:46 [INFO] Step 60000 - time/fps: 21
# 2026-05-07 14:37:46 [INFO] Step 60000 - time/time_elapsed: 2822
# 2026-05-07 14:37:46 [INFO] Step 60000 - time/total_timesteps: 60000
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/learning_rate: 0.0003
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/entropy_loss: -1.757019680738449
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/policy_gradient_loss: -0.004212618854944594
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/value_loss: 1117.4732311248779
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/approx_kl: 0.0071614328771829605
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/clip_fraction: 0.066552734375
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/loss: 371.39654541015625
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/explained_variance: 0.5720416307449341
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/n_updates: 300
# 2026-05-07 14:39:29 [INFO] Step 62000 - train/clip_range: 0.2
# 2026-05-07 14:39:29 [INFO] Step 62000 - time/iterations: 31
# 2026-05-07 14:39:29 [INFO] Step 62000 - time/fps: 21
# 2026-05-07 14:39:29 [INFO] Step 62000 - time/time_elapsed: 2925
# 2026-05-07 14:39:29 [INFO] Step 62000 - time/total_timesteps: 62000
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/learning_rate: 0.0003
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/entropy_loss: -1.7190736223012208
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/policy_gradient_loss: -0.00454643522753031
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/value_loss: 1143.475274848938
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/approx_kl: 0.010371389798820019
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/clip_fraction: 0.07548828125
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/loss: 425.10931396484375
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/explained_variance: 0.5444110631942749
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/n_updates: 310
# 2026-05-07 14:41:08 [INFO] Step 64000 - train/clip_range: 0.2
# 2026-05-07 14:41:08 [INFO] Step 64000 - time/iterations: 32
# 2026-05-07 14:41:08 [INFO] Step 64000 - time/fps: 21
# 2026-05-07 14:41:08 [INFO] Step 64000 - time/time_elapsed: 3025
# 2026-05-07 14:41:08 [INFO] Step 64000 - time/total_timesteps: 64000
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/learning_rate: 0.0003
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/entropy_loss: -1.6877925455570222
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/policy_gradient_loss: -0.0018050607279292308
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/value_loss: 1050.7083126068114
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/approx_kl: 0.007792276330292225
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/clip_fraction: 0.0341796875
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/loss: 712.0462646484375
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/explained_variance: 0.5781147480010986
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/n_updates: 320
# 2026-05-07 14:42:49 [INFO] Step 66000 - train/clip_range: 0.2
# 2026-05-07 14:42:49 [INFO] Step 66000 - time/iterations: 33
# 2026-05-07 14:42:49 [INFO] Step 66000 - time/fps: 21
# 2026-05-07 14:42:49 [INFO] Step 66000 - time/time_elapsed: 3126
# 2026-05-07 14:42:49 [INFO] Step 66000 - time/total_timesteps: 66000
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/learning_rate: 0.0003
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/entropy_loss: -1.7062541216611862
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/policy_gradient_loss: -0.0072557767576654445
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/value_loss: 1077.9359904289245
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/approx_kl: 0.011206282302737236
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/clip_fraction: 0.0947265625
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/loss: 487.55230712890625
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/explained_variance: 0.5997498035430908
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/n_updates: 330
# 2026-05-07 14:44:31 [INFO] Step 68000 - train/clip_range: 0.2
# 2026-05-07 14:44:31 [INFO] Step 68000 - time/iterations: 34
# 2026-05-07 14:44:31 [INFO] Step 68000 - time/fps: 21
# 2026-05-07 14:44:31 [INFO] Step 68000 - time/time_elapsed: 3228
# 2026-05-07 14:44:31 [INFO] Step 68000 - time/total_timesteps: 68000
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/learning_rate: 0.0003
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/entropy_loss: -1.7023641467094421
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/policy_gradient_loss: -0.003577420643705409
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/value_loss: 1233.5956085205078
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/approx_kl: 0.007404566276818514
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/clip_fraction: 0.06376953125
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/loss: 1142.77880859375
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/explained_variance: 0.6338958740234375
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/n_updates: 340
# 2026-05-07 14:46:14 [INFO] Step 70000 - train/clip_range: 0.2
# 2026-05-07 14:46:14 [INFO] Step 70000 - time/iterations: 35
# 2026-05-07 14:46:14 [INFO] Step 70000 - time/fps: 21
# 2026-05-07 14:46:14 [INFO] Step 70000 - time/time_elapsed: 3330
# 2026-05-07 14:46:14 [INFO] Step 70000 - time/total_timesteps: 70000
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/learning_rate: 0.0003
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/entropy_loss: -1.6706912636756897
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/policy_gradient_loss: -0.0034459752452676183
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/value_loss: 1275.6967782974243
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/approx_kl: 0.01023181527853012
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/clip_fraction: 0.08525390625
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/loss: 516.3070068359375
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/explained_variance: 0.48967069387435913
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/n_updates: 350
# 2026-05-07 14:47:56 [INFO] Step 72000 - train/clip_range: 0.2
# 2026-05-07 14:47:56 [INFO] Step 72000 - time/iterations: 36
# 2026-05-07 14:47:56 [INFO] Step 72000 - time/fps: 20
# 2026-05-07 14:47:56 [INFO] Step 72000 - time/time_elapsed: 3433
# 2026-05-07 14:47:56 [INFO] Step 72000 - time/total_timesteps: 72000
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/learning_rate: 0.0003
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/entropy_loss: -1.6958348885178567
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/policy_gradient_loss: -0.0021605224726954477
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/value_loss: 911.730594921112
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/approx_kl: 0.003941062837839127
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/clip_fraction: 0.057421875
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/loss: 684.5106811523438
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/explained_variance: 0.7120777368545532
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/n_updates: 360
# 2026-05-07 14:49:36 [INFO] Step 74000 - train/clip_range: 0.2
# 2026-05-07 14:49:36 [INFO] Step 74000 - time/iterations: 37
# 2026-05-07 14:49:36 [INFO] Step 74000 - time/fps: 20
# 2026-05-07 14:49:36 [INFO] Step 74000 - time/time_elapsed: 3533
# 2026-05-07 14:49:36 [INFO] Step 74000 - time/total_timesteps: 74000
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/learning_rate: 0.0003
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/entropy_loss: -1.6474750436842442
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/policy_gradient_loss: -0.005164984073780942
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/value_loss: 1142.4452512741088
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/approx_kl: 0.007939007133245468
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/clip_fraction: 0.072119140625
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/loss: 715.91455078125
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/explained_variance: 0.6076239943504333
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/n_updates: 370
# 2026-05-07 14:51:15 [INFO] Step 76000 - train/clip_range: 0.2
# 2026-05-07 14:51:15 [INFO] Step 76000 - time/iterations: 38
# 2026-05-07 14:51:15 [INFO] Step 76000 - time/fps: 20
# 2026-05-07 14:51:15 [INFO] Step 76000 - time/time_elapsed: 3631
# 2026-05-07 14:51:15 [INFO] Step 76000 - time/total_timesteps: 76000
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/learning_rate: 0.0003
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/entropy_loss: -1.6405639465898276
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/policy_gradient_loss: -0.006515529711032286
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/value_loss: 1156.4459394454957
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/approx_kl: 0.012295139022171497
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/clip_fraction: 0.098681640625
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/loss: 525.8013305664062
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/explained_variance: 0.6664060354232788
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/n_updates: 380
# 2026-05-07 14:52:54 [INFO] Step 78000 - train/clip_range: 0.2
# 2026-05-07 14:52:54 [INFO] Step 78000 - time/iterations: 39
# 2026-05-07 14:52:54 [INFO] Step 78000 - time/fps: 20
# 2026-05-07 14:52:54 [INFO] Step 78000 - time/time_elapsed: 3731
# 2026-05-07 14:52:54 [INFO] Step 78000 - time/total_timesteps: 78000
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/learning_rate: 0.0003
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/entropy_loss: -1.6062982313334941
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/policy_gradient_loss: -0.0056441953740431925
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/value_loss: 1046.9639498710633
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/approx_kl: 0.015109356492757797
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/clip_fraction: 0.108349609375
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/loss: 1259.8035888671875
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/explained_variance: 0.6570677161216736
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/n_updates: 390
# 2026-05-07 14:54:34 [INFO] Step 80000 - train/clip_range: 0.2
# 2026-05-07 14:54:34 [INFO] Step 80000 - time/iterations: 40
# 2026-05-07 14:54:34 [INFO] Step 80000 - time/fps: 20
# 2026-05-07 14:54:34 [INFO] Step 80000 - time/time_elapsed: 3830
# 2026-05-07 14:54:34 [INFO] Step 80000 - time/total_timesteps: 80000
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/learning_rate: 0.0003
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/entropy_loss: -1.5448945973068475
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/policy_gradient_loss: -0.008717874909052625
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/value_loss: 866.6570441246033
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/approx_kl: 0.01412634551525116
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/clip_fraction: 0.097607421875
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/loss: 248.50946044921875
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/explained_variance: 0.7076452970504761
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/n_updates: 400
# 2026-05-07 14:56:13 [INFO] Step 82000 - train/clip_range: 0.2
# 2026-05-07 14:56:13 [INFO] Step 82000 - time/iterations: 41
# 2026-05-07 14:56:13 [INFO] Step 82000 - time/fps: 20
# 2026-05-07 14:56:13 [INFO] Step 82000 - time/time_elapsed: 3930
# 2026-05-07 14:56:13 [INFO] Step 82000 - time/total_timesteps: 82000
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/learning_rate: 0.0003
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/entropy_loss: -1.5579596985131503
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/policy_gradient_loss: -0.004078922880580649
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/value_loss: 1093.4048225402832
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/approx_kl: 0.007507514674216509
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/clip_fraction: 0.057080078125
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/loss: 699.4534912109375
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/explained_variance: 0.6040790677070618
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/n_updates: 410
# 2026-05-07 14:57:52 [INFO] Step 84000 - train/clip_range: 0.2
# 2026-05-07 14:57:52 [INFO] Step 84000 - time/iterations: 42
# 2026-05-07 14:57:52 [INFO] Step 84000 - time/fps: 20
# 2026-05-07 14:57:52 [INFO] Step 84000 - time/time_elapsed: 4029
# 2026-05-07 14:57:52 [INFO] Step 84000 - time/total_timesteps: 84000
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/learning_rate: 0.0003
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/entropy_loss: -1.5420528091490269
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/policy_gradient_loss: -0.0007078562572132796
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/value_loss: 1087.4858951568604
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/approx_kl: 0.012029032222926617
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/clip_fraction: 0.042431640625
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/loss: 237.74278259277344
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/explained_variance: 0.6304992437362671
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/n_updates: 420
# 2026-05-07 14:59:36 [INFO] Step 86000 - train/clip_range: 0.2
# 2026-05-07 14:59:36 [INFO] Step 86000 - time/iterations: 43
# 2026-05-07 14:59:36 [INFO] Step 86000 - time/fps: 20
# 2026-05-07 14:59:36 [INFO] Step 86000 - time/time_elapsed: 4132
# 2026-05-07 14:59:36 [INFO] Step 86000 - time/total_timesteps: 86000
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/learning_rate: 0.0003
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/entropy_loss: -1.6148795541375875
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/policy_gradient_loss: -0.0024653584288898854
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/value_loss: 909.7043943405151
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/approx_kl: 0.0073755825869739056
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/clip_fraction: 0.044921875
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/loss: 476.08673095703125
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/explained_variance: 0.7089710235595703
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/n_updates: 430
# 2026-05-07 15:01:19 [INFO] Step 88000 - train/clip_range: 0.2
# 2026-05-07 15:01:19 [INFO] Step 88000 - time/iterations: 44
# 2026-05-07 15:01:19 [INFO] Step 88000 - time/fps: 20
# 2026-05-07 15:01:19 [INFO] Step 88000 - time/time_elapsed: 4236
# 2026-05-07 15:01:19 [INFO] Step 88000 - time/total_timesteps: 88000
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/learning_rate: 0.0003
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/entropy_loss: -1.538084701821208
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/policy_gradient_loss: -0.0018072810373269022
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/value_loss: 931.4763117790222
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/approx_kl: 0.005640537478029728
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/clip_fraction: 0.02705078125
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/loss: 404.3277587890625
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/explained_variance: 0.5689702033996582
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/n_updates: 440
# 2026-05-07 15:03:04 [INFO] Step 90000 - train/clip_range: 0.2
# 2026-05-07 15:03:04 [INFO] Step 90000 - time/iterations: 45
# 2026-05-07 15:03:04 [INFO] Step 90000 - time/fps: 20
# 2026-05-07 15:03:04 [INFO] Step 90000 - time/time_elapsed: 4340
# 2026-05-07 15:03:04 [INFO] Step 90000 - time/total_timesteps: 90000
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/learning_rate: 0.0003
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/entropy_loss: -1.5962161995470523
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/policy_gradient_loss: -0.0045611916953930635
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/value_loss: 688.7984335899353
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/approx_kl: 0.009149339981377125
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/clip_fraction: 0.066455078125
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/loss: 126.36033630371094
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/explained_variance: 0.7625289559364319
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/n_updates: 450
# 2026-05-07 15:04:54 [INFO] Step 92000 - train/clip_range: 0.2
# 2026-05-07 15:04:54 [INFO] Step 92000 - time/iterations: 46
# 2026-05-07 15:04:54 [INFO] Step 92000 - time/fps: 20
# 2026-05-07 15:04:54 [INFO] Step 92000 - time/time_elapsed: 4450
# 2026-05-07 15:04:54 [INFO] Step 92000 - time/total_timesteps: 92000
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/learning_rate: 0.0003
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/entropy_loss: -1.5717072788625956
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/policy_gradient_loss: -0.0024343498473172074
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/value_loss: 886.4732563972473
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/approx_kl: 0.004339295439422131
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/clip_fraction: 0.055810546875
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/loss: 1055.693115234375
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/explained_variance: 0.6624526381492615
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/n_updates: 460
# 2026-05-07 15:06:39 [INFO] Step 94000 - train/clip_range: 0.2
# 2026-05-07 15:06:39 [INFO] Step 94000 - time/iterations: 47
# 2026-05-07 15:06:39 [INFO] Step 94000 - time/fps: 20
# 2026-05-07 15:06:39 [INFO] Step 94000 - time/time_elapsed: 4555
# 2026-05-07 15:06:39 [INFO] Step 94000 - time/total_timesteps: 94000
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/learning_rate: 0.0003
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/entropy_loss: -1.6392398577183485
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/policy_gradient_loss: -0.004334973149525467
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/value_loss: 870.9240682601928
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/approx_kl: 0.009062717668712139
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/clip_fraction: 0.0853515625
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/loss: 291.4554443359375
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/explained_variance: 0.7059304714202881
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/n_updates: 470
# 2026-05-07 15:08:23 [INFO] Step 96000 - train/clip_range: 0.2
# 2026-05-07 15:08:23 [INFO] Step 96000 - time/iterations: 48
# 2026-05-07 15:08:23 [INFO] Step 96000 - time/fps: 20
# 2026-05-07 15:08:23 [INFO] Step 96000 - time/time_elapsed: 4660
# 2026-05-07 15:08:23 [INFO] Step 96000 - time/total_timesteps: 96000
# ...
# 2026-05-07 15:58:21 [INFO] Step 154000 - train/policy_gradient_loss: -0.00037736508093075825
# 2026-05-07 15:58:21 [INFO] Step 154000 - train/value_loss: 751.1317921638489
# 2026-05-07 15:58:21 [INFO] Step 154000 - train/approx_kl: 0.0014380307402461767
# 2026-05-07 15:58:21 [INFO] Step 154000 - train/clip_fraction: 0.01318359375
# 2026-05-07 15:58:21 [INFO] Step 154000 - train/loss: 698.7726440429688
# 2026-05-07 15:58:21 [INFO] Step 154000 - train/explained_variance: 0.7499721050262451
# 2026-05-07 15:58:21 [INFO] Step 154000 - train/n_updates: 760
# 2026-05-07 15:58:21 [INFO] Step 154000 - train/clip_range: 0.2
# 2026-05-07 15:58:21 [INFO] Step 154000 - time/iterations: 77
# 2026-05-07 15:58:21 [INFO] Step 154000 - time/fps: 20
# 2026-05-07 15:58:21 [INFO] Step 154000 - time/time_elapsed: 7658
# 2026-05-07 15:58:21 [INFO] Step 154000 - time/total_timesteps: 154000
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/learning_rate: 0.0003
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/entropy_loss: -0.5758324766531586
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/policy_gradient_loss: 6.370323826558888e-05
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/value_loss: 986.9360776901245
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/approx_kl: 0.0015830259071663022
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/clip_fraction: 0.0158203125
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/loss: 281.1637268066406
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/explained_variance: 0.6527197360992432
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/n_updates: 770
# 2026-05-07 16:00:11 [INFO] Step 156000 - train/clip_range: 0.2
# 2026-05-07 16:00:11 [INFO] Step 156000 - time/iterations: 78
# 2026-05-07 16:00:11 [INFO] Step 156000 - time/fps: 20
# 2026-05-07 16:00:11 [INFO] Step 156000 - time/time_elapsed: 7767
# 2026-05-07 16:00:11 [INFO] Step 156000 - time/total_timesteps: 156000
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/learning_rate: 0.0003
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/entropy_loss: -0.5695280646905303
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/policy_gradient_loss: -0.0013471792262862436
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/value_loss: 980.407900428772
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/approx_kl: 0.0017038376536220312
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/clip_fraction: 0.01748046875
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/loss: 312.0330810546875
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/explained_variance: 0.6688456535339355
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/n_updates: 780
# 2026-05-07 16:02:16 [INFO] Step 158000 - train/clip_range: 0.2
# 2026-05-07 16:02:16 [INFO] Step 158000 - time/iterations: 79
# 2026-05-07 16:02:16 [INFO] Step 158000 - time/fps: 20
# 2026-05-07 16:02:16 [INFO] Step 158000 - time/time_elapsed: 7892
# 2026-05-07 16:02:16 [INFO] Step 158000 - time/total_timesteps: 158000
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/learning_rate: 0.0003
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/entropy_loss: -0.5182382418774069
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/policy_gradient_loss: 0.00025367636771989055
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/value_loss: 794.845663356781
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/approx_kl: 0.0015970144886523485
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/clip_fraction: 0.015283203125
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/loss: 165.79315185546875
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/explained_variance: 0.7149707078933716
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/n_updates: 790
# 2026-05-07 16:04:14 [INFO] Step 160000 - train/clip_range: 0.2
# 2026-05-07 16:04:14 [INFO] Step 160000 - time/iterations: 80
# 2026-05-07 16:04:14 [INFO] Step 160000 - time/fps: 19
# 2026-05-07 16:04:14 [INFO] Step 160000 - time/time_elapsed: 8011
# 2026-05-07 16:04:14 [INFO] Step 160000 - time/total_timesteps: 160000
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/learning_rate: 0.0003
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/entropy_loss: -0.47329699592664837
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/policy_gradient_loss: -0.0021237453453068155
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/value_loss: 883.1646788597106
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/approx_kl: 0.0016240780241787434
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/clip_fraction: 0.025830078125
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/loss: 309.0118713378906
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/explained_variance: 0.7069369554519653
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/n_updates: 800
# 2026-05-07 16:06:07 [INFO] Step 162000 - train/clip_range: 0.2
# 2026-05-07 16:06:07 [INFO] Step 162000 - time/iterations: 81
# 2026-05-07 16:06:07 [INFO] Step 162000 - time/fps: 19
# 2026-05-07 16:06:07 [INFO] Step 162000 - time/time_elapsed: 8124
# 2026-05-07 16:06:07 [INFO] Step 162000 - time/total_timesteps: 162000
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/learning_rate: 0.0003
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/entropy_loss: -0.4693521008826792
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/policy_gradient_loss: -0.0009052959336258937
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/value_loss: 1687.2947827339171
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/approx_kl: 0.0014778089243918657
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/clip_fraction: 0.011962890625
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/loss: 679.19580078125
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/explained_variance: 0.7253941297531128
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/n_updates: 810
# 2026-05-07 16:07:59 [INFO] Step 164000 - train/clip_range: 0.2
# 2026-05-07 16:07:59 [INFO] Step 164000 - time/iterations: 82
# 2026-05-07 16:07:59 [INFO] Step 164000 - time/fps: 19
# 2026-05-07 16:07:59 [INFO] Step 164000 - time/time_elapsed: 8235
# 2026-05-07 16:07:59 [INFO] Step 164000 - time/total_timesteps: 164000
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/learning_rate: 0.0003
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/entropy_loss: -0.5236324571073055
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/policy_gradient_loss: -0.0020777158279088326
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/value_loss: 1336.1806043624879
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/approx_kl: 0.0015220779459923506
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/clip_fraction: 0.043310546875
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/loss: 222.55926513671875
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/explained_variance: 0.48189520835876465
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/n_updates: 820
# 2026-05-07 16:09:54 [INFO] Step 166000 - train/clip_range: 0.2
# 2026-05-07 16:09:54 [INFO] Step 166000 - time/iterations: 83
# 2026-05-07 16:09:54 [INFO] Step 166000 - time/fps: 19
# 2026-05-07 16:09:54 [INFO] Step 166000 - time/time_elapsed: 8350
# 2026-05-07 16:09:54 [INFO] Step 166000 - time/total_timesteps: 166000
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/learning_rate: 0.0003
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/entropy_loss: -0.41357157938182354
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/policy_gradient_loss: 0.0020622677737264896
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/value_loss: 1704.1803817749023
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/approx_kl: 0.012602278962731361
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/clip_fraction: 0.0498046875
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/loss: 617.7169799804688
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/explained_variance: 0.35053813457489014
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/n_updates: 830
# 2026-05-07 16:11:51 [INFO] Step 168000 - train/clip_range: 0.2
# 2026-05-07 16:11:51 [INFO] Step 168000 - time/iterations: 84
# 2026-05-07 16:11:51 [INFO] Step 168000 - time/fps: 19
# 2026-05-07 16:11:51 [INFO] Step 168000 - time/time_elapsed: 8468
# 2026-05-07 16:11:51 [INFO] Step 168000 - time/total_timesteps: 168000
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/learning_rate: 0.0003
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/entropy_loss: -0.33713277261704205
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/policy_gradient_loss: -0.00036602665786631403
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/value_loss: 1385.3503784179688
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/approx_kl: 0.0007869663531892002
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/clip_fraction: 0.010888671875
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/loss: 654.5133666992188
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/explained_variance: 0.5010278820991516
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/n_updates: 840
# 2026-05-07 16:13:52 [INFO] Step 170000 - train/clip_range: 0.2
# 2026-05-07 16:13:52 [INFO] Step 170000 - time/iterations: 85
# 2026-05-07 16:13:52 [INFO] Step 170000 - time/fps: 19
# 2026-05-07 16:13:52 [INFO] Step 170000 - time/time_elapsed: 8588
# 2026-05-07 16:13:52 [INFO] Step 170000 - time/total_timesteps: 170000
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/learning_rate: 0.0003
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/entropy_loss: -0.3054382253438234
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/policy_gradient_loss: -2.977840085804928e-05
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/value_loss: 1752.0080131530763
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/approx_kl: 0.002395619172602892
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/clip_fraction: 0.0205078125
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/loss: 1183.9808349609375
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/explained_variance: 0.3483399748802185
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/n_updates: 850
# 2026-05-07 16:15:43 [INFO] Step 172000 - train/clip_range: 0.2
# 2026-05-07 16:15:43 [INFO] Step 172000 - time/iterations: 86
# 2026-05-07 16:15:43 [INFO] Step 172000 - time/fps: 19
# 2026-05-07 16:15:43 [INFO] Step 172000 - time/time_elapsed: 8699
# 2026-05-07 16:15:43 [INFO] Step 172000 - time/total_timesteps: 172000
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/learning_rate: 0.0003
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/entropy_loss: -0.24816821389831603
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/policy_gradient_loss: -0.00019770757644437252
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/value_loss: 1418.270873451233
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/approx_kl: 0.0021516000851988792
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/clip_fraction: 0.008349609375
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/loss: 899.115966796875
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/explained_variance: 0.5056825876235962
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/n_updates: 860
# 2026-05-07 16:17:35 [INFO] Step 174000 - train/clip_range: 0.2
# 2026-05-07 16:17:35 [INFO] Step 174000 - time/iterations: 87
# 2026-05-07 16:17:35 [INFO] Step 174000 - time/fps: 19
# 2026-05-07 16:17:35 [INFO] Step 174000 - time/time_elapsed: 8811
# 2026-05-07 16:17:35 [INFO] Step 174000 - time/total_timesteps: 174000
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/learning_rate: 0.0003
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/entropy_loss: -0.2390952968969941
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/policy_gradient_loss: -0.0008338246567291208
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/value_loss: 1395.385638999939
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/approx_kl: 0.0004527604323811829
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/clip_fraction: 0.005615234375
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/loss: 251.09689331054688
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/explained_variance: 0.36750179529190063
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/n_updates: 870
# 2026-05-07 16:19:28 [INFO] Step 176000 - train/clip_range: 0.2
# 2026-05-07 16:19:28 [INFO] Step 176000 - time/iterations: 88
# 2026-05-07 16:19:28 [INFO] Step 176000 - time/fps: 19
# 2026-05-07 16:19:28 [INFO] Step 176000 - time/time_elapsed: 8925
# 2026-05-07 16:19:28 [INFO] Step 176000 - time/total_timesteps: 176000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1299/2010520818.py in <cell line: 0>()
#      10     # prime_policy_for_combo(model, SuperMarioCombo.RIGHT_RUN, ppo_env, logger, iterations=1)
#      11     logger.info("Starting training...")
# ---> 12     model.learn(total_timesteps=500000)
#      13     model.save("ppo_mario_trained")
#      14 except Exception as e:
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309         progress_bar: bool = False,
#     310     ) -> SelfPPO:
# --> 311         return super().learn(
#     312             total_timesteps=total_timesteps,
#     313             callback=callback,
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     322
#     323         while self.num_timesteps < total_timesteps:
# --> 324             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325
#     326             if not continue_training:
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     216                     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     217
# --> 218             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     219
#     220             self.num_timesteps += env.num_envs
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     220         """
#     221         self.step_async(actions)
# --> 222         return self.step_wait()
#     223
#     224     def get_images(self) -> Sequence[np.ndarray | None]:
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      57         # Avoid circular imports
#      58         for env_idx in range(self.num_envs):
# ---> 59             obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60                 self.actions[env_idx]
#      61             )
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/core.py in step(self, action)
#     558     ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     559         """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 560         observation, reward, terminated, truncated, info = self.env.step(action)
#     561         return self.observation(observation), reward, terminated, truncated, info
#     562
#
# /usr/local/lib/python3.12/dist-packages/gymnasium/core.py in step(self, action)
#     634     ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     635         """Runs the :attr:`env` :meth:`env.step` using the modified ``action`` from :meth:`self.action`."""
# --> 636         return self.env.step(self.action(action))
#     637
#     638     def action(self, action: WrapperActType) -> ActType:
#
# /usr/local/lib/python3.12/dist-packages/mario_the_explorer/environment/layered_observation_env.py in step(self, action)
#      78         if self.limit_fps_to is not None:
#      79             for _ in range(self.frames_per_action - 1):
# ---> 80                 _, _, _, _, info = self.env.step(action)
#      81         _, _, _, _, info = self.env.step(action)
#      82         self._current_step += 1
#
# /usr/local/lib/python3.12/dist-packages/stable_retro/retro_env.py in step(self, a)
#     248             self.movie.step()
#     249         self.em.step()
# --> 250         self.data.update_ram()
#     251         ob = self._update_obs()
#     252         rew, done, info = self.compute_step()
#
# KeyboardInterrupt:

# %%
from gymnasium.wrappers import RecordVideo

try:
    env.env.env.limit_fps_to = None
    video_env = RecordVideo(env, video_folder="./", name_prefix=f"trained-{RUN_NAME}", episode_trigger=lambda x: True)
    obs, info = video_env.reset()
    done = False
    step_count = 0
    while not done:
        env.render()
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = video_env.step(action)
        step_count += 1
        if step_count % 1000 == 0:
            logger.info(f"Step: {step_count}")
        done = terminated or truncated
        if done:
            logger.info(f"Terminated: {terminated}")
            logger.info(f"Truncated: {truncated}")
except Exception as e:
    logger.error(e)
    raise e
finally:
    video_env.close()

# %%
try:
    env.env.env.limit_fps_to = 5
    ppo_env = DummyVecEnv([lambda: env])
    policy_kwargs = dict(
        features_extractor_class=CustomMarioCNN,
        features_extractor_kwargs=dict(features_dim=512),
    )
    model = PPO.load("ppo_mario_trained")
    model.set_logger(ppo_logger)
    # prime_policy_for_combo(model, SuperMarioCombo.RIGHT_RUN, ppo_env, logger, iterations=1)
    logger.info("Starting training...")
    model.learn(total_timesteps=5000000)
    model.save("ppo_mario_full_train")
except Exception as e:
    logger.error(e)
    raise e
finally:
    env.reset()

# %%
from gymnasium.wrappers import RecordVideo

try:
    env.env.env.limit_fps_to = None
    video_env = RecordVideo(env, video_folder="./", name_prefix=f"full-train-{RUN_NAME}", episode_trigger=lambda x: True)
    obs, info = video_env.reset()
    done = False
    step_count = 0
    while not done:
        env.render()
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = video_env.step(action)
        step_count += 1
        if step_count % 1000 == 0:
            logger.info(f"Step: {step_count}")
        done = terminated or truncated
        if done:
            logger.info(f"Terminated: {terminated}")
            logger.info(f"Truncated: {truncated}")
except Exception as e:
    logger.error(e)
    raise e
finally:
    video_env.close()

# %%
try:
    env.env.env.limit_fps_to = 5
    ppo_env = DummyVecEnv([lambda: env])
    policy_kwargs = dict(
        features_extractor_class=CustomMarioCNN,
        features_extractor_kwargs=dict(features_dim=512),
    )
    model = PPO("CnnPolicy", ppo_env, policy_kwargs=policy_kwargs, verbose=1, learning_rate=0.0003, n_steps=3000, device=device)
    model.set_logger(ppo_logger)
    # prime_policy_for_combo(model, SuperMarioCombo.RIGHT_RUN, ppo_env, logger, iterations=1)
    logger.info("Starting training...")
    model.learn(total_timesteps=50000000)
    model.save("ppo_mario_full_train")
except Exception as e:
    logger.error(e)
    raise e
finally:
    env.reset()
