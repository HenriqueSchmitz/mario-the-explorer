# %%
# !git clone https://github.com/HenriqueSchmitz/mario-the-explorer
# Out:
# Cloning into 'mario-the-explorer'...
# remote: Enumerating objects: 243, done.
# remote: Counting objects: 100% (243/243), done.
# remote: Compressing objects: 100% (142/142), done.
# remote: Total 243 (delta 109), reused 190 (delta 65), pack-reused 0 (from 0)
# Receiving objects: 100% (243/243), 798.60 KiB | 3.97 MiB/s, done.
# Resolving deltas: 100% (109/109), done.

# %%
# !sh ./mario-the-explorer/setup.sh
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.1/123.1 MB 121.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 353.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 313.6 MB/s eta 0:00:00
#   Building wheel for mario-the-explorer (pyproject.toml) ... done
# Importing SuperMarioWorld-Snes-v0
# Imported 1 games

# %%
# !pip install -q stable-baselines3
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 24.2 MB/s eta 0:00:00

# %%
from typing import Optional
from enum import Enum
from logging import Logger

import torch
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import KVWriter, Logger as PpoLogger

from mario_the_explorer import (MultiAttemptSuperMarioWorldEmulator, RewardModel, ScreenOverlay, Tile, get_file_logger,
                                tile_absolute_id, TileEncoder, SuperMarioAction, SuperMarioCombo, SuperMarioDiscretizer,
                                prime_policy_for_combo, TileType)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class Direction(Enum):
    LEFT = 0
    RIGHT = 1
    UP = 2
    DOWN = 3

# %%
from mario_the_explorer.environment import tiles
class TryThingsRewardModel(RewardModel):
    def __init__(self):
        self._blocks_seen = set()
        self._block_action_counts = {}

    def reset(self) -> None:
        self._blocks_seen = set()
        self._block_action_counts = {}

    def get_reward(self,
                   action: list[int],
                   observation: list[list[Tile]],
                   terminated: bool,
                   truncated: bool,
                   info: dict) -> float:
        reward = -0.01
        for row in observation:
            for tile in row:
                tile_id = tile_absolute_id(tile)
                if tile_id not in self._blocks_seen:
                    self._blocks_seen.add(tile_id)
                    reward += 10.0
        tiles_around_mario = self._get_tiles_around_mario(observation)
        for tile_and_direction in tiles_around_mario:
            combo_id = SuperMarioCombo.get_combo_id_from_action(action)
            interaction_id = (combo_id, tile_and_direction[0], tile_and_direction[1])
            action_reward = 0.0
            if interaction_id not in self._block_action_counts:
                self._block_action_counts[interaction_id] = 0
            self._block_action_counts[interaction_id] += 1
            action_reward = 1.0 / (self._block_action_counts[interaction_id]**2)
            if action_reward < 0.05:
                action_reward = 0.0
            reward += action_reward
        return reward

    def _get_tiles_around_mario(self, observation: list[list[Tile]]) -> set[tuple[Direction, int]]:
        mario_coordinates = self._find_mario_coordinates(observation)
        blocks_around_mario = set()
        if not mario_coordinates:
            return blocks_around_mario
        for mario_row, mario_col in mario_coordinates:
            if mario_row > 0:
                block_above_mario = observation[mario_row - 1][mario_col]
                if block_above_mario["type"] != TileType.MARIO and block_above_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.UP.name, tile_absolute_id(block_above_mario)))
            if mario_row < len(observation) - 1:
                block_below_mario = observation[mario_row + 1][mario_col]
                if block_below_mario["type"] != TileType.MARIO and block_below_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.DOWN.name, tile_absolute_id(block_below_mario)))
            if mario_col > 0:
                block_left_of_mario = observation[mario_row][mario_col - 1]
                if block_left_of_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.LEFT.name, tile_absolute_id(block_left_of_mario)))
            if mario_col < len(observation[0]) - 1:
                block_right_of_mario = observation[mario_row][mario_col + 1]
                if block_right_of_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.RIGHT.name, tile_absolute_id(block_right_of_mario)))
        return blocks_around_mario


    def _find_mario_coordinates(self, observation: list[list[Tile]]) -> list[tuple[int, int]]:
        mario_coordinates = []
        for row_idx, row in enumerate(observation):
            for col_idx, tile in enumerate(row):
                if tile["type"] == TileType.MARIO:
                    mario_coordinates.append((row_idx, col_idx))
        return mario_coordinates

# %%
class MarioReshapeWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        # Get the original H, W (14, 16)
        h, w = self.observation_space.shape
        # Redefine the space to include a single channel (1, 14, 16)
        self.observation_space = gym.spaces.Box(
            low=0,
            high=255,
            shape=(1, h, w),
            dtype=np.float32
        )

    def observation(self, obs):
        # Add the channel dimension
        return np.expand_dims(obs, axis=0).astype(np.float32)

# %%
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
import torch.nn as nn

class CustomMarioCNN(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 64):
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]

        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 4, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(4, 16, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            sample_tensor = torch.as_tensor(observation_space.sample()[None]).float()
            n_flatten = self.cnn(sample_tensor).shape[1]

        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU()
        )

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))

# %%
RUN_NAME = "cnn_action_rewards"
LEVEL = "DonutPlains1"
LOG_LEVEL = "INFO"
ATTEMPTS = 1

# %%
class PpoKvWriter(KVWriter):
    def __init__(self, logger: Logger):
        self._logger = logger

    def write(self, key_values, key_excluded, step=0):
        for key, value in key_values.items():
            self._logger.info(f"Step {step} - {key}: {value}")

    def close(self):
        pass

# %%
logger = get_file_logger(RUN_NAME, LOG_LEVEL)
ppo_logger = PpoLogger(
    folder=None,
    output_formats=[PpoKvWriter(logger)]
)
base_env = MultiAttemptSuperMarioWorldEmulator(level = LEVEL,
                                               render_mode = "rgb_array",
                                               reward_model = TryThingsRewardModel(),
                                               attempts = ATTEMPTS,
                                               render_debug = True,
                                               render_grid = True,
                                               logger = logger)
env = SuperMarioDiscretizer(base_env)
env = MarioReshapeWrapper(env)
# Out:
# 2026-05-05 03:49:01 [INFO] Session log for run cnn_action_rewards with level [INFO] initialized at: cnn_action_rewards_20260505_034901.log

# %%
try:
    ppo_env = DummyVecEnv([lambda: env])
    policy_kwargs = dict(
        features_extractor_class=CustomMarioCNN,
        features_extractor_kwargs=dict(features_dim=64),
    )
    model = PPO("CnnPolicy", ppo_env, policy_kwargs=policy_kwargs, verbose=1, learning_rate=0.0003, n_steps=10000, device=device)
    model.set_logger(ppo_logger)
    prime_policy_for_combo(model, SuperMarioCombo.RIGHT_RUN, ppo_env, logger, iterations=1)
    logger.info("Starting training...")
    model.learn(total_timesteps=60000)
    model.save("ppo_mario_test")
except Exception as e:
    logger.error(e)
    raise e
finally:
    env.reset()
# Out:
# Using cpu device
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/ppo/ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 10000`, after every 156 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=10000 and n_envs=1)
#   warnings.warn(
# 2026-05-05 03:49:07 [INFO] Priming policy to prefer 'RIGHT_RUN'
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# 2026-05-05 03:49:07 [INFO] Priming complete
# 2026-05-05 03:49:07 [INFO] Starting training...
# 2026-05-05 03:49:47 [INFO] Step 10000 - time/iterations: 1
# 2026-05-05 03:49:47 [INFO] Step 10000 - time/fps: 250
# 2026-05-05 03:49:47 [INFO] Step 10000 - time/time_elapsed: 39
# 2026-05-05 03:49:47 [INFO] Step 10000 - time/total_timesteps: 10000
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/learning_rate: 0.0003
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/entropy_loss: -2.394288875039216
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/policy_gradient_loss: -0.0029775589007504616
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/value_loss: 1.0341743227497788
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/approx_kl: 0.006296585313975811
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/clip_fraction: 0.032872213375796176
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/loss: 0.08714893460273743
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/explained_variance: -0.0062427520751953125
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/n_updates: 10
# 2026-05-05 03:50:37 [INFO] Step 20000 - train/clip_range: 0.2
# 2026-05-05 03:50:37 [INFO] Step 20000 - time/iterations: 2
# 2026-05-05 03:50:37 [INFO] Step 20000 - time/fps: 221
# 2026-05-05 03:50:37 [INFO] Step 20000 - time/time_elapsed: 90
# 2026-05-05 03:50:37 [INFO] Step 20000 - time/total_timesteps: 20000
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/learning_rate: 0.0003
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/entropy_loss: -2.378716535628981
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/policy_gradient_loss: -0.005051288268993057
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/value_loss: 1.5463508485988446
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/approx_kl: 0.009804400615394115
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/clip_fraction: 0.07375597133757962
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/loss: 0.019799713045358658
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/explained_variance: -0.02731490135192871
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/n_updates: 20
# 2026-05-05 03:51:29 [INFO] Step 30000 - train/clip_range: 0.2
# 2026-05-05 03:51:29 [INFO] Step 30000 - time/iterations: 3
# 2026-05-05 03:51:29 [INFO] Step 30000 - time/fps: 211
# 2026-05-05 03:51:29 [INFO] Step 30000 - time/time_elapsed: 142
# 2026-05-05 03:51:29 [INFO] Step 30000 - time/total_timesteps: 30000
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/learning_rate: 0.0003
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/entropy_loss: -2.3576321837249075
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/policy_gradient_loss: -0.005193464900515261
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/value_loss: 3.8802129561544225
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/approx_kl: 0.010725084692239761
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/clip_fraction: 0.1172173566878981
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/loss: 0.410383015871048
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/explained_variance: 0.057233572006225586
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/n_updates: 30
# 2026-05-05 03:52:19 [INFO] Step 40000 - train/clip_range: 0.2
# 2026-05-05 03:52:19 [INFO] Step 40000 - time/iterations: 4
# 2026-05-05 03:52:19 [INFO] Step 40000 - time/fps: 208
# 2026-05-05 03:52:19 [INFO] Step 40000 - time/time_elapsed: 192
# 2026-05-05 03:52:19 [INFO] Step 40000 - time/total_timesteps: 40000
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/learning_rate: 0.0003
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/entropy_loss: -2.341210816772121
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/policy_gradient_loss: -0.00735725533012538
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/value_loss: 8.060322428319106
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/approx_kl: 0.010501543991267681
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/clip_fraction: 0.055901671974522296
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/loss: 0.8539028763771057
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/explained_variance: 0.221418559551239
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/n_updates: 40
# 2026-05-05 03:53:10 [INFO] Step 50000 - train/clip_range: 0.2
# 2026-05-05 03:53:10 [INFO] Step 50000 - time/iterations: 5
# 2026-05-05 03:53:10 [INFO] Step 50000 - time/fps: 205
# 2026-05-05 03:53:10 [INFO] Step 50000 - time/time_elapsed: 243
# 2026-05-05 03:53:10 [INFO] Step 50000 - time/total_timesteps: 50000
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/learning_rate: 0.0003
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/entropy_loss: -2.31287703681144
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/policy_gradient_loss: -0.004873826327158292
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/value_loss: 15.357781947494312
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/approx_kl: 0.00744679244235158
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/clip_fraction: 0.05094546178343949
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/loss: 2.418245792388916
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/explained_variance: 0.284756064414978
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/n_updates: 50
# 2026-05-05 03:54:02 [INFO] Step 60000 - train/clip_range: 0.2
# 2026-05-05 03:54:02 [INFO] Step 60000 - time/iterations: 6
# 2026-05-05 03:54:02 [INFO] Step 60000 - time/fps: 203
# 2026-05-05 03:54:02 [INFO] Step 60000 - time/time_elapsed: 295
# 2026-05-05 03:54:02 [INFO] Step 60000 - time/total_timesteps: 60000

# %%
from gymnasium.wrappers import RecordVideo

try:
    video_env = RecordVideo(env, video_folder="./", name_prefix=f"trial-{RUN_NAME}", episode_trigger=lambda x: True)
    obs, info = video_env.reset()
    done = False
    step_count = 0
    while not done:
        env.render()
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = video_env.step(action)
        step_count += 1
        if step_count % 1000 == 0:
            logger.info(f"Step: {step_count}")
        done = terminated or truncated
        if done:
            logger.info(f"Terminated: {terminated}")
            logger.info(f"Truncated: {truncated}")
except Exception as e:
    logger.error(e)
    raise e
finally:
    video_env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /content folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 2026-05-05 03:54:16 [INFO] Terminated: True
# 2026-05-05 03:54:16 [INFO] Truncated: False
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
try:
    ppo_env = DummyVecEnv([lambda: env])
    policy_kwargs = dict(
        features_extractor_class=CustomMarioCNN,
        features_extractor_kwargs=dict(features_dim=64),
    )
    model = PPO("CnnPolicy", ppo_env, policy_kwargs=policy_kwargs, verbose=1, learning_rate=0.0003, n_steps=20000, device=device)
    model.set_logger(ppo_logger)
    prime_policy_for_combo(model, SuperMarioCombo.RIGHT_RUN, ppo_env, logger, iterations=1)
    logger.info("Starting training...")
    model.learn(total_timesteps=500000)
    model.save("ppo_mario_test")
except Exception as e:
    logger.error(e)
    raise e
finally:
    env.reset()
# Out:
# 2026-05-05 03:54:18 [INFO] Priming policy to prefer 'RIGHT_RUN'
# 2026-05-05 03:54:18 [INFO] Priming complete
# 2026-05-05 03:54:18 [INFO] Starting training...
# Using cpu device
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/learning_rate: 0.0003
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/entropy_loss: -2.3015484764317797
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/policy_gradient_loss: -0.004966705053404069
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/value_loss: 24.224900788714173
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/approx_kl: 0.007372522260993719
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/clip_fraction: 0.05862858280254777
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/loss: 4.7039923667907715
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/explained_variance: 0.4397647976875305
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/n_updates: 60
# 2026-05-05 03:56:28 [INFO] Step 32000 - train/clip_range: 0.2
# 2026-05-05 03:56:28 [INFO] Step 32000 - time/iterations: 1
# 2026-05-05 03:56:28 [INFO] Step 32000 - time/fps: 244
# 2026-05-05 03:56:28 [INFO] Step 32000 - time/time_elapsed: 130
# 2026-05-05 03:56:28 [INFO] Step 32000 - time/total_timesteps: 32000
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/learning_rate: 0.0003
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/entropy_loss: -2.3921329696178435
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/policy_gradient_loss: -0.0032891088615870103
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/value_loss: 0.7861613210305571
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/approx_kl: 0.00909478310495615
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/clip_fraction: 0.0546375
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/loss: 0.02436223439872265
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/explained_variance: -0.006769418716430664
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/n_updates: 10
# 2026-05-05 03:59:10 [INFO] Step 64000 - train/clip_range: 0.2
# 2026-05-05 03:59:10 [INFO] Step 64000 - time/iterations: 2
# 2026-05-05 03:59:10 [INFO] Step 64000 - time/fps: 219
# 2026-05-05 03:59:10 [INFO] Step 64000 - time/time_elapsed: 292
# 2026-05-05 03:59:10 [INFO] Step 64000 - time/total_timesteps: 64000
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/learning_rate: 0.0003
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/entropy_loss: -2.3821810312747957
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/policy_gradient_loss: -0.004163668937748298
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/value_loss: 1.031092935265228
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/approx_kl: 0.00867223460227251
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/clip_fraction: 0.05399375
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/loss: 0.012080017477273941
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/explained_variance: 0.09640049934387207
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/n_updates: 20
# 2026-05-05 04:02:02 [INFO] Step 96000 - train/clip_range: 0.2
# 2026-05-05 04:02:02 [INFO] Step 96000 - time/iterations: 3
# 2026-05-05 04:02:02 [INFO] Step 96000 - time/fps: 206
# 2026-05-05 04:02:02 [INFO] Step 96000 - time/time_elapsed: 463
# 2026-05-05 04:02:02 [INFO] Step 96000 - time/total_timesteps: 96000
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/learning_rate: 0.0003
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/entropy_loss: -2.374450799369812
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/policy_gradient_loss: -0.005472946449369192
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/value_loss: 0.929360572008416
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/approx_kl: 0.011501842178404331
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/clip_fraction: 0.110965625
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/loss: 0.04416443780064583
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/explained_variance: 0.13773632049560547
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/n_updates: 30
# 2026-05-05 04:04:57 [INFO] Step 128000 - train/clip_range: 0.2
# 2026-05-05 04:04:57 [INFO] Step 128000 - time/iterations: 4
# 2026-05-05 04:04:57 [INFO] Step 128000 - time/fps: 200
# 2026-05-05 04:04:57 [INFO] Step 128000 - time/time_elapsed: 639
# 2026-05-05 04:04:57 [INFO] Step 128000 - time/total_timesteps: 128000
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/learning_rate: 0.0003
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/entropy_loss: -2.376639180898666
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/policy_gradient_loss: -0.003535405687848106
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/value_loss: 0.9036358493171632
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/approx_kl: 0.008806137368083
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/clip_fraction: 0.04479375
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/loss: 0.04144365340471268
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/explained_variance: 0.2672387957572937
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/n_updates: 40
# 2026-05-05 04:07:51 [INFO] Step 160000 - train/clip_range: 0.2
# 2026-05-05 04:07:51 [INFO] Step 160000 - time/iterations: 5
# 2026-05-05 04:07:51 [INFO] Step 160000 - time/fps: 196
# 2026-05-05 04:07:51 [INFO] Step 160000 - time/time_elapsed: 813
# 2026-05-05 04:07:51 [INFO] Step 160000 - time/total_timesteps: 160000
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/learning_rate: 0.0003
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/entropy_loss: -2.3528277230262757
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/policy_gradient_loss: -0.004643823229754343
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/value_loss: 0.8651443312451244
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/approx_kl: 0.011086951941251755
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/clip_fraction: 0.107971875
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/loss: 0.04276738315820694
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/explained_variance: 0.03372734785079956
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/n_updates: 50
# 2026-05-05 04:10:38 [INFO] Step 192000 - train/clip_range: 0.2
# 2026-05-05 04:10:38 [INFO] Step 192000 - time/iterations: 6
# 2026-05-05 04:10:38 [INFO] Step 192000 - time/fps: 195
# 2026-05-05 04:10:38 [INFO] Step 192000 - time/time_elapsed: 980
# 2026-05-05 04:10:38 [INFO] Step 192000 - time/total_timesteps: 192000
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/learning_rate: 0.0003
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/entropy_loss: -2.3290085604190827
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/policy_gradient_loss: -0.005312423272058367
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/value_loss: 0.883899666685611
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/approx_kl: 0.012261457741260529
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/clip_fraction: 0.107525
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/loss: 2.4773826599121094
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/explained_variance: 0.06928902864456177
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/n_updates: 60
# 2026-05-05 04:13:27 [INFO] Step 224000 - train/clip_range: 0.2
# 2026-05-05 04:13:27 [INFO] Step 224000 - time/iterations: 7
# 2026-05-05 04:13:27 [INFO] Step 224000 - time/fps: 194
# 2026-05-05 04:13:27 [INFO] Step 224000 - time/time_elapsed: 1149
# 2026-05-05 04:13:27 [INFO] Step 224000 - time/total_timesteps: 224000
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/learning_rate: 0.0003
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/entropy_loss: -2.3124319907665254
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/policy_gradient_loss: -0.005575631167786196
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/value_loss: 0.7349347672745585
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/approx_kl: 0.014775350689888
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/clip_fraction: 0.1336375
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/loss: 0.6658301949501038
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/explained_variance: 0.05826866626739502
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/n_updates: 70
# 2026-05-05 04:16:30 [INFO] Step 256000 - train/clip_range: 0.2
# 2026-05-05 04:16:30 [INFO] Step 256000 - time/iterations: 8
# 2026-05-05 04:16:30 [INFO] Step 256000 - time/fps: 192
# 2026-05-05 04:16:30 [INFO] Step 256000 - time/time_elapsed: 1331
# 2026-05-05 04:16:30 [INFO] Step 256000 - time/total_timesteps: 256000
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/learning_rate: 0.0003
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/entropy_loss: -2.3034652827739714
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/policy_gradient_loss: -0.005669560148683377
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/value_loss: 0.6125977323818952
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/approx_kl: 0.011947723105549812
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/clip_fraction: 0.134490625
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/loss: 0.12913617491722107
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/explained_variance: 0.041216909885406494
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/n_updates: 80
# 2026-05-05 04:19:29 [INFO] Step 288000 - train/clip_range: 0.2
# 2026-05-05 04:19:29 [INFO] Step 288000 - time/iterations: 9
# 2026-05-05 04:19:29 [INFO] Step 288000 - time/fps: 190
# 2026-05-05 04:19:29 [INFO] Step 288000 - time/time_elapsed: 1510
# 2026-05-05 04:19:29 [INFO] Step 288000 - time/total_timesteps: 288000
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/learning_rate: 0.0003
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/entropy_loss: -2.3000042384147643
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/policy_gradient_loss: -0.0054220490479376165
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/value_loss: 0.9879108709432185
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/approx_kl: 0.010460276156663895
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/clip_fraction: 0.1044375
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/loss: 0.12716102600097656
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/explained_variance: 0.13467955589294434
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/n_updates: 90
# 2026-05-05 04:22:20 [INFO] Step 320000 - train/clip_range: 0.2
# 2026-05-05 04:22:20 [INFO] Step 320000 - time/iterations: 10
# 2026-05-05 04:22:20 [INFO] Step 320000 - time/fps: 190
# 2026-05-05 04:22:20 [INFO] Step 320000 - time/time_elapsed: 1682
# 2026-05-05 04:22:20 [INFO] Step 320000 - time/total_timesteps: 320000
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/learning_rate: 0.0003
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/entropy_loss: -2.2807864587783815
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/policy_gradient_loss: -0.005626157100161072
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/value_loss: 1.0245547648787499
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/approx_kl: 0.01416453905403614
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/clip_fraction: 0.1597875
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/loss: 0.320498526096344
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/explained_variance: 0.04672396183013916
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/n_updates: 100
# 2026-05-05 04:25:12 [INFO] Step 352000 - train/clip_range: 0.2
# 2026-05-05 04:25:12 [INFO] Step 352000 - time/iterations: 11
# 2026-05-05 04:25:12 [INFO] Step 352000 - time/fps: 189
# 2026-05-05 04:25:12 [INFO] Step 352000 - time/time_elapsed: 1853
# 2026-05-05 04:25:12 [INFO] Step 352000 - time/total_timesteps: 352000
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/learning_rate: 0.0003
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/entropy_loss: -2.2505611267089844
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/policy_gradient_loss: -0.006036666766181588
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/value_loss: 0.9095360730381683
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/approx_kl: 0.015438268892467022
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/clip_fraction: 0.125065625
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/loss: 0.25482165813446045
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/explained_variance: -0.1193772554397583
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/n_updates: 110
# 2026-05-05 04:27:54 [INFO] Step 384000 - train/clip_range: 0.2
# 2026-05-05 04:27:54 [INFO] Step 384000 - time/iterations: 12
# 2026-05-05 04:27:54 [INFO] Step 384000 - time/fps: 190
# 2026-05-05 04:27:54 [INFO] Step 384000 - time/time_elapsed: 2016
# 2026-05-05 04:27:54 [INFO] Step 384000 - time/total_timesteps: 384000
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/learning_rate: 0.0003
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/entropy_loss: -2.1944929157733917
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/policy_gradient_loss: -0.004866556415264495
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/value_loss: 1.4734066950805484
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/approx_kl: 0.011136362329125404
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/clip_fraction: 0.104609375
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/loss: 2.2726879119873047
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/explained_variance: 0.23164498805999756
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/n_updates: 120
# 2026-05-05 04:30:39 [INFO] Step 416000 - train/clip_range: 0.2
# 2026-05-05 04:30:39 [INFO] Step 416000 - time/iterations: 13
# 2026-05-05 04:30:39 [INFO] Step 416000 - time/fps: 190
# 2026-05-05 04:30:39 [INFO] Step 416000 - time/time_elapsed: 2181
# 2026-05-05 04:30:39 [INFO] Step 416000 - time/total_timesteps: 416000
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/learning_rate: 0.0003
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/entropy_loss: -2.1573376549243926
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/policy_gradient_loss: -0.003743821720778942
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/value_loss: 2.3040424514502287
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/approx_kl: 0.009521158412098885
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/clip_fraction: 0.0858375
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/loss: 2.7453505992889404
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/explained_variance: 0.3956330418586731
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/n_updates: 130
# 2026-05-05 04:33:24 [INFO] Step 448000 - train/clip_range: 0.2
# 2026-05-05 04:33:24 [INFO] Step 448000 - time/iterations: 14
# 2026-05-05 04:33:24 [INFO] Step 448000 - time/fps: 190
# 2026-05-05 04:33:24 [INFO] Step 448000 - time/time_elapsed: 2345
# 2026-05-05 04:33:24 [INFO] Step 448000 - time/total_timesteps: 448000
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/learning_rate: 0.0003
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/entropy_loss: -2.1339636955738066
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/policy_gradient_loss: -0.0035764183057122863
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/value_loss: 2.171656519803405
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/approx_kl: 0.009244388900697231
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/clip_fraction: 0.0882375
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/loss: 0.22291970252990723
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/explained_variance: 0.3368721008300781
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/n_updates: 140
# 2026-05-05 04:36:08 [INFO] Step 480000 - train/clip_range: 0.2
# 2026-05-05 04:36:08 [INFO] Step 480000 - time/iterations: 15
# 2026-05-05 04:36:08 [INFO] Step 480000 - time/fps: 191
# 2026-05-05 04:36:08 [INFO] Step 480000 - time/time_elapsed: 2509
# 2026-05-05 04:36:08 [INFO] Step 480000 - time/total_timesteps: 480000
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/learning_rate: 0.0003
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/entropy_loss: -2.1069816152095795
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/policy_gradient_loss: -0.0028300956947728993
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/value_loss: 2.317524456381798
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/approx_kl: 0.009531719610095024
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/clip_fraction: 0.084934375
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/loss: 0.16348406672477722
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/explained_variance: 0.4339246153831482
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/n_updates: 150
# 2026-05-05 04:38:53 [INFO] Step 512000 - train/clip_range: 0.2
# 2026-05-05 04:38:53 [INFO] Step 512000 - time/iterations: 16
# 2026-05-05 04:38:53 [INFO] Step 512000 - time/fps: 191
# 2026-05-05 04:38:53 [INFO] Step 512000 - time/time_elapsed: 2675
# 2026-05-05 04:38:53 [INFO] Step 512000 - time/total_timesteps: 512000

# %%
from gymnasium.wrappers import RecordVideo

try:
    video_env = RecordVideo(env, video_folder="./", name_prefix=f"trained-{RUN_NAME}", episode_trigger=lambda x: True)
    obs, info = video_env.reset()
    done = False
    step_count = 0
    while not done:
        env.render()
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = video_env.step(action)
        step_count += 1
        if step_count % 1000 == 0:
            logger.info(f"Step: {step_count}")
        done = terminated or truncated
        if done:
            logger.info(f"Terminated: {terminated}")
            logger.info(f"Truncated: {truncated}")
except Exception as e:
    logger.error(e)
    raise e
finally:
    video_env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /content folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 2026-05-05 04:39:30 [INFO] Step: 1000
# 2026-05-05 04:39:36 [INFO] Step: 2000
# 2026-05-05 04:39:41 [INFO] Step: 3000
# 2026-05-05 04:39:47 [INFO] Step: 4000
# 2026-05-05 04:39:52 [INFO] Step: 5000
# 2026-05-05 04:39:58 [INFO] Step: 6000
# 2026-05-05 04:40:03 [INFO] Step: 7000
# 2026-05-05 04:40:09 [INFO] Step: 8000
# 2026-05-05 04:40:14 [INFO] Step: 9000
# 2026-05-05 04:40:19 [INFO] Step: 10000
# 2026-05-05 04:40:25 [INFO] Step: 11000
# 2026-05-05 04:40:30 [INFO] Step: 12000
# 2026-05-05 04:40:36 [INFO] Step: 13000
# 2026-05-05 04:40:41 [INFO] Step: 14000
# 2026-05-05 04:40:47 [INFO] Step: 15000
# 2026-05-05 04:40:53 [INFO] Step: 16000
# 2026-05-05 04:40:56 [INFO] Terminated: True
# 2026-05-05 04:40:56 [INFO] Truncated: False
