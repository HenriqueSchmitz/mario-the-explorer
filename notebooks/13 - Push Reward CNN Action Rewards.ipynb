# %%
# !git clone https://github.com/HenriqueSchmitz/mario-the-explorer
# Out:
# Cloning into 'mario-the-explorer'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (237/237), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 237 (delta 105), reused 186 (delta 63), pack-reused 0 (from 0)
# Receiving objects: 100% (237/237), 798.23 KiB | 3.58 MiB/s, done.
# Resolving deltas: 100% (105/105), done.

# %%
# !sh ./mario-the-explorer/setup.sh
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 200.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.1/123.1 MB 93.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 352.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 195.9 MB/s eta 0:00:00
#   Building wheel for mario-the-explorer (pyproject.toml) ... done
# Importing SuperMarioWorld-Snes-v0
# Imported 1 games

# %%
# !pip install -q stable-baselines3
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 41.6 MB/s eta 0:00:00

# %%
from typing import Optional
from enum import Enum
from logging import Logger

import torch
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import KVWriter, Logger as PpoLogger

from mario_the_explorer import (MultiAttemptSuperMarioWorldEmulator, RewardModel, ScreenOverlay, Tile, get_file_logger,
                                tile_absolute_id, TileEncoder, SuperMarioAction, SuperMarioCombo, SuperMarioDiscretizer,
                                prime_policy_for_combo, TileType)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class Direction(Enum):
    LEFT = 0
    RIGHT = 1
    UP = 2
    DOWN = 3

# %%
from mario_the_explorer.environment import tiles
class TryThingsRewardModel(RewardModel):
    def __init__(self):
        self._blocks_seen = set()
        self._block_action_counts = {}

    def reset(self) -> None:
        self._blocks_seen = set()
        self._block_action_counts = {}

    def get_reward(self,
                   action: list[int],
                   observation: list[list[Tile]],
                   terminated: bool,
                   truncated: bool,
                   info: dict) -> float:
        reward = -0.01
        for row in observation:
            for tile in row:
                tile_id = tile_absolute_id(tile)
                if tile_id not in self._blocks_seen:
                    self._blocks_seen.add(tile_id)
                    reward += 10.0
        tiles_around_mario = self._get_tiles_around_mario(observation)
        for tile_and_direction in tiles_around_mario:
            action_reward = 0.0
            if tile_and_direction not in self._block_action_counts:
                self._block_action_counts[tile_and_direction] = 0
            self._block_action_counts[tile_and_direction] += 1
            action_reward = 1.0 / (self._block_action_counts[tile_and_direction]**2)
            if action_reward < 0.05:
                action_reward = 0.0
            reward += action_reward
        return reward

    def _get_tiles_around_mario(self, observation: list[list[Tile]]) -> set[tuple[Direction, int]]:
        mario_coordinates = self._find_mario_coordinates(observation)
        blocks_around_mario = set()
        if not mario_coordinates:
            return blocks_around_mario
        for mario_row, mario_col in mario_coordinates:
            if mario_row > 0:
                block_above_mario = observation[mario_row - 1][mario_col]
                if block_above_mario["type"] != TileType.MARIO and block_above_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.UP.name, tile_absolute_id(block_above_mario)))
            if mario_row < len(observation) - 1:
                block_below_mario = observation[mario_row + 1][mario_col]
                if block_below_mario["type"] != TileType.MARIO and block_below_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.DOWN.name, tile_absolute_id(block_below_mario)))
            if mario_col > 0:
                block_left_of_mario = observation[mario_row][mario_col - 1]
                if block_left_of_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.LEFT.name, tile_absolute_id(block_left_of_mario)))
            if mario_col < len(observation[0]) - 1:
                block_right_of_mario = observation[mario_row][mario_col + 1]
                if block_right_of_mario["type"] != TileType.EMPTY:
                    blocks_around_mario.add((Direction.RIGHT.name, tile_absolute_id(block_right_of_mario)))
        return blocks_around_mario


    def _find_mario_coordinates(self, observation: list[list[Tile]]) -> list[tuple[int, int]]:
        mario_coordinates = []
        for row_idx, row in enumerate(observation):
            for col_idx, tile in enumerate(row):
                if tile["type"] == TileType.MARIO:
                    mario_coordinates.append((row_idx, col_idx))
        return mario_coordinates

# %%
class MarioReshapeWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        # Get the original H, W (14, 16)
        h, w = self.observation_space.shape
        # Redefine the space to include a single channel (1, 14, 16)
        self.observation_space = gym.spaces.Box(
            low=0,
            high=255,
            shape=(1, h, w),
            dtype=np.float32
        )

    def observation(self, obs):
        # Add the channel dimension
        return np.expand_dims(obs, axis=0).astype(np.float32)

# %%
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
import torch.nn as nn

class CustomMarioCNN(BaseFeaturesExtractor):
    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 64):
        super().__init__(observation_space, features_dim)
        n_input_channels = observation_space.shape[0]

        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 4, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(4, 16, kernel_size=3, stride=2),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            sample_tensor = torch.as_tensor(observation_space.sample()[None]).float()
            n_flatten = self.cnn(sample_tensor).shape[1]

        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU()
        )

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))

# %%
RUN_NAME = "cnn_action_rewards"
LEVEL = "DonutPlains1"
LOG_LEVEL = "INFO"
ATTEMPTS = 1

# %%
class PpoKvWriter(KVWriter):
    def __init__(self, logger: Logger):
        self._logger = logger

    def write(self, key_values, key_excluded, step=0):
        for key, value in key_values.items():
            self._logger.info(f"Step {step} - {key}: {value}")

    def close(self):
        pass

# %%
logger = get_file_logger(RUN_NAME, LOG_LEVEL)
ppo_logger = PpoLogger(
    folder=None,
    output_formats=[PpoKvWriter(logger)]
)
base_env = MultiAttemptSuperMarioWorldEmulator(level = LEVEL,
                                               render_mode = "rgb_array",
                                               reward_model = TryThingsRewardModel(),
                                               attempts = ATTEMPTS,
                                               render_debug = True,
                                               render_grid = True,
                                               logger = logger)
env = SuperMarioDiscretizer(base_env)
env = MarioReshapeWrapper(env)
# Out:
# 2026-05-05 02:34:47 [INFO] Session log for run cnn_action_rewards with level [INFO] initialized at: cnn_action_rewards_20260505_023447.log

# %%
try:
    ppo_env = DummyVecEnv([lambda: env])
    policy_kwargs = dict(
        features_extractor_class=CustomMarioCNN,
        features_extractor_kwargs=dict(features_dim=64),
    )
    model = PPO("CnnPolicy", ppo_env, policy_kwargs=policy_kwargs, verbose=1, learning_rate=0.0003, n_steps=10000, device=device)
    model.set_logger(ppo_logger)
    prime_policy_for_combo(model, SuperMarioCombo.RIGHT_RUN, ppo_env, logger, iterations=1)
    logger.info("Starting training...")
    model.learn(total_timesteps=60000)
    model.save("ppo_mario_test")
except Exception as e:
    logger.error(e)
    raise e
finally:
    env.reset()
# Out:
# Using cpu device
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/ppo/ppo.py:155: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 10000`, after every 156 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=10000 and n_envs=1)
#   warnings.warn(
# 2026-05-05 02:34:54 [INFO] Priming policy to prefer 'RIGHT_RUN'
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# 2026-05-05 02:34:54 [INFO] Priming complete
# 2026-05-05 02:34:54 [INFO] Starting training...
# 2026-05-05 02:35:39 [INFO] Step 10000 - time/iterations: 1
# 2026-05-05 02:35:39 [INFO] Step 10000 - time/fps: 220
# 2026-05-05 02:35:39 [INFO] Step 10000 - time/time_elapsed: 45
# 2026-05-05 02:35:39 [INFO] Step 10000 - time/total_timesteps: 10000
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/learning_rate: 0.0003
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/entropy_loss: -2.3900017648745493
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/policy_gradient_loss: -0.005385880458471217
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/value_loss: 0.5036823196315958
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/approx_kl: 0.019322076812386513
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/clip_fraction: 0.05099522292993631
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/loss: -0.052472468465566635
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/explained_variance: -0.0011790990829467773
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/n_updates: 10
# 2026-05-05 02:36:34 [INFO] Step 20000 - train/clip_range: 0.2
# 2026-05-05 02:36:34 [INFO] Step 20000 - time/iterations: 2
# 2026-05-05 02:36:34 [INFO] Step 20000 - time/fps: 200
# 2026-05-05 02:36:34 [INFO] Step 20000 - time/time_elapsed: 99
# 2026-05-05 02:36:34 [INFO] Step 20000 - time/total_timesteps: 20000
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/learning_rate: 0.0003
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/entropy_loss: -2.374097461305606
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/policy_gradient_loss: -0.006193152805167446
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/value_loss: 0.5969401376198081
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/approx_kl: 0.011573546566069126
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/clip_fraction: 0.10845939490445859
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/loss: 0.008486015722155571
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/explained_variance: 0.0006670355796813965
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/n_updates: 20
# 2026-05-05 02:37:34 [INFO] Step 30000 - train/clip_range: 0.2
# 2026-05-05 02:37:34 [INFO] Step 30000 - time/iterations: 3
# 2026-05-05 02:37:34 [INFO] Step 30000 - time/fps: 186
# 2026-05-05 02:37:34 [INFO] Step 30000 - time/time_elapsed: 160
# 2026-05-05 02:37:34 [INFO] Step 30000 - time/total_timesteps: 30000
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/learning_rate: 0.0003
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/entropy_loss: -2.2938194596843355
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/policy_gradient_loss: -0.001962788610357293
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/value_loss: 2.0583272948849256
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/approx_kl: 0.00919190514832735
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/clip_fraction: 0.11668988853503184
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/loss: 0.04943722486495972
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/explained_variance: 0.07465380430221558
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/n_updates: 30
# 2026-05-05 02:38:31 [INFO] Step 40000 - train/clip_range: 0.2
# 2026-05-05 02:38:31 [INFO] Step 40000 - time/iterations: 4
# 2026-05-05 02:38:31 [INFO] Step 40000 - time/fps: 184
# 2026-05-05 02:38:31 [INFO] Step 40000 - time/time_elapsed: 217
# 2026-05-05 02:38:31 [INFO] Step 40000 - time/total_timesteps: 40000
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/learning_rate: 0.0003
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/entropy_loss: -2.3166574232137886
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/policy_gradient_loss: -0.0050123307243683584
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/value_loss: 2.379430192319237
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/approx_kl: 0.010028825141489506
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/clip_fraction: 0.11068869426751593
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/loss: 0.014148222282528877
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/explained_variance: 0.14379560947418213
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/n_updates: 40
# 2026-05-05 02:39:29 [INFO] Step 50000 - train/clip_range: 0.2
# 2026-05-05 02:39:29 [INFO] Step 50000 - time/iterations: 5
# 2026-05-05 02:39:29 [INFO] Step 50000 - time/fps: 181
# 2026-05-05 02:39:29 [INFO] Step 50000 - time/time_elapsed: 275
# 2026-05-05 02:39:29 [INFO] Step 50000 - time/total_timesteps: 50000
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/learning_rate: 0.0003
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/entropy_loss: -2.2647935982722385
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/policy_gradient_loss: -0.005835260297498031
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/value_loss: 0.7089123654515915
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/approx_kl: 0.012192752212285995
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/clip_fraction: 0.12482085987261146
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/loss: 0.13424760103225708
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/explained_variance: 0.25632208585739136
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/n_updates: 50
# 2026-05-05 02:40:24 [INFO] Step 60000 - train/clip_range: 0.2
# 2026-05-05 02:40:24 [INFO] Step 60000 - time/iterations: 6
# 2026-05-05 02:40:24 [INFO] Step 60000 - time/fps: 181
# 2026-05-05 02:40:24 [INFO] Step 60000 - time/time_elapsed: 330
# 2026-05-05 02:40:24 [INFO] Step 60000 - time/total_timesteps: 60000

# %%
from gymnasium.wrappers import RecordVideo

try:
    video_env = RecordVideo(env, video_folder="./", name_prefix=f"trial-{RUN_NAME}", episode_trigger=lambda x: True)
    obs, info = video_env.reset()
    done = False
    step_count = 0
    while not done:
        env.render()
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = video_env.step(action)
        step_count += 1
        if step_count % 1000 == 0:
            logger.info(f"Step: {step_count}")
        done = terminated or truncated
        if done:
            logger.info(f"Terminated: {terminated}")
            logger.info(f"Truncated: {truncated}")
except Exception as e:
    logger.error(e)
    raise e
finally:
    video_env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /content folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 2026-05-05 02:40:40 [INFO] Step: 1000
# 2026-05-05 02:40:45 [INFO] Step: 2000
# 2026-05-05 02:40:51 [INFO] Step: 3000
# 2026-05-05 02:40:56 [INFO] Step: 4000
# 2026-05-05 02:41:02 [INFO] Step: 5000
# 2026-05-05 02:41:07 [INFO] Step: 6000
# 2026-05-05 02:41:13 [INFO] Step: 7000
# 2026-05-05 02:41:18 [INFO] Step: 8000
# 2026-05-05 02:41:24 [INFO] Step: 9000
# 2026-05-05 02:41:29 [INFO] Step: 10000
# 2026-05-05 02:41:35 [INFO] Step: 11000
# 2026-05-05 02:41:40 [INFO] Step: 12000
# 2026-05-05 02:41:46 [INFO] Step: 13000
# 2026-05-05 02:41:52 [INFO] Step: 14000
# 2026-05-05 02:41:57 [INFO] Step: 15000
# 2026-05-05 02:42:03 [INFO] Step: 16000
# 2026-05-05 02:42:06 [INFO] Terminated: True
# 2026-05-05 02:42:06 [INFO] Truncated: False
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
try:
    ppo_env = DummyVecEnv([lambda: env])
    policy_kwargs = dict(
        features_extractor_class=CustomMarioCNN,
        features_extractor_kwargs=dict(features_dim=64),
    )
    model = PPO("CnnPolicy", ppo_env, policy_kwargs=policy_kwargs, verbose=1, learning_rate=0.0003, n_steps=32000, device=device)
    model.set_logger(ppo_logger)
    prime_policy_for_combo(model, SuperMarioCombo.RIGHT_RUN, ppo_env, logger, iterations=1)
    logger.info("Starting training...")
    model.learn(total_timesteps=500000)
    model.save("ppo_mario_test")
except Exception as e:
    logger.error(e)
    raise e
finally:
    env.reset()
# Out:
# 2026-05-05 02:43:23 [INFO] Priming policy to prefer 'RIGHT_RUN'
# 2026-05-05 02:43:23 [INFO] Priming complete
# 2026-05-05 02:43:23 [INFO] Starting training...
# Using cpu device
# 2026-05-05 02:45:42 [INFO] Step 32000 - train/learning_rate: 0.0003
# 2026-05-05 02:45:42 [INFO] Step 32000 - train
# 2026-05-05 02:57:23 [INFO] Step 160000 - train/loss: 1.255065679550171
# 2026-05-05 02:57:23 [INFO] Step 160000 - train/explained_variance: 0.29088449478149414
# 2026-05-05 02:57:23 [INFO] Step 160000 - train/n_updates: 40
# 2026-05-05 02:57:23 [INFO] Step 160000 - train/clip_range: 0.2
# 2026-05-05 02:57:23 [INFO] Step 160000 - time/iterations: 5
# 2026-05-05 02:57:23 [INFO] Step 160000 - time/fps: 190
# 2026-05-05 02:57:23 [INFO] Step 160000 - time/time_elapsed: 840
# 2026-05-05 02:57:23 [INFO] Step 160000 - time/total_timesteps: 160000
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/learning_rate: 0.0003
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/entropy_loss: -2.297615479850769
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/policy_gradient_loss: -0.003882608452113345
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/value_loss: 7.817027787351608
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/approx_kl: 0.012703842483460903
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/clip_fraction: 0.14029375
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/loss: 0.9136260747909546
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/explained_variance: 0.46817725896835327
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/n_updates: 50
# 2026-05-05 03:00:21 [INFO] Step 192000 - train/clip_range: 0.2
# 2026-05-05 03:00:21 [INFO] Step 192000 - time/iterations: 6
# 2026-05-05 03:00:21 [INFO] Step 192000 - time/fps: 188
# 2026-05-05 03:00:21 [INFO] Step 192000 - time/time_elapsed: 1017
# 2026-05-05 03:00:21 [INFO] Step 192000 - time/total_timesteps: 192000
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/learning_rate: 0.0003
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/entropy_loss: -2.2923023500919344
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/policy_gradient_loss: -0.004182672062981874
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/value_loss: 5.618062364280224
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/approx_kl: 0.015085428021848202
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/clip_fraction: 0.173490625
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/loss: 2.4844253063201904
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/explained_variance: 0.5722358822822571
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/n_updates: 60
# 2026-05-05 03:03:17 [INFO] Step 224000 - train/clip_range: 0.2
# 2026-05-05 03:03:17 [INFO] Step 224000 - time/iterations: 7
# 2026-05-05 03:03:17 [INFO] Step 224000 - time/fps: 187
# 2026-05-05 03:03:17 [INFO] Step 224000 - time/time_elapsed: 1194
# 2026-05-05 03:03:17 [INFO] Step 224000 - time/total_timesteps: 224000
# 2026-05-05 03:06:16 [INFO] Step 256000 - train/learning_rate: 0.0003
# 2026-05-05 03:06:16 [INFO] Step 256000 - train/entropy_loss: -2.2718021334171294
# 2026-05-05 03:06:16 [INFO] Step 256000 - train/policy_gradient_loss: -0.0033890625916887076
# 2026-05-05 03:06:16 [INFO] Step 256000 - train/value_loss: 9.133477124357224
# 2026-05-05 03:06:16 [INFO] Step 256000 - train/approx_kl: 0.013576749712228775
# 2026-05-05 03:06:16 [INFO] Step 256000 - train/clip_fraction: 0.1476
# 2026-05-05 03:06:16 [INFO] Step 256000 - train/loss: 2.0923643112182617
# 2026-05-05 03:06:16 [INFO] Step 256000 - train/explained_variance: 0.6617266535758972
# 2026-05-05 03:06:17 [INFO] Step 256000 - train/n_updates: 70
# 2026-05-05 03:06:17 [INFO] Step 256000 - train/clip_range: 0.2
# 2026-05-05 03:06:17 [INFO] Step 256000 - time/iterations: 8
# 2026-05-05 03:06:17 [INFO] Step 256000 - time/fps: 186
# 2026-05-05 03:06:17 [INFO] Step 256000 - time/time_elapsed: 1373
# 2026-05-05 03:06:17 [INFO] Step 256000 - time/total_timesteps: 256000
# 2026-05-05 03:09:17 [INFO] Step 288000 - train/learning_rate: 0.0003
# 2026-05-05 03:09:17 [INFO] Step 288000 - train/entropy_loss: -2.269756948900223
# 2026-05-05 03:09:17 [INFO] Step 288000 - train/policy_gradient_loss: -0.0021803585547022523
# 2026-05-05 03:09:17 [INFO] Step 288000 - train/value_loss: 6.0725846885800365
# 2026-05-05 03:09:17 [INFO] Step 288000 - train/approx_kl: 0.015486828982830048
# 2026-05-05 03:09:17 [INFO] Step 288000 - train/clip_fraction: 0.196559375
# 2026-05-05 03:09:17 [INFO] Step 288000 - train/loss: 1.3954774141311646
# 2026-05-05 03:09:17 [INFO] Step 288000 - train/explained_variance: 0.7671139240264893
# 2026-05-05 03:09:17 [INFO] Step 288000 - train
# 2026-05-05 03:21:11 [INFO] Step 416000 - train/n_updates: 120
# 2026-05-05 03:21:11 [INFO] Step 416000 - train/clip_range: 0.2
# 2026-05-05 03:21:11 [INFO] Step 416000 - time/iterations: 13
# 2026-05-05 03:21:11 [INFO] Step 416000 - time/fps: 183
# 2026-05-05 03:21:11 [INFO] Step 416000 - time/time_elapsed: 2268
# 2026-05-05 03:21:11 [INFO] Step 416000 - time/total_timesteps: 416000
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/learning_rate: 0.0003
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/entropy_loss: -2.12426574511528
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/policy_gradient_loss: -0.0012551503729075193
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/value_loss: 18.928236169576646
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/approx_kl: 0.014182678423821926
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/clip_fraction: 0.162540625
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/loss: 8.12794017791748
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/explained_variance: 0.8157072067260742
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/n_updates: 130
# 2026-05-05 03:24:06 [INFO] Step 448000 - train/clip_range: 0.2
# 2026-05-05 03:24:06 [INFO] Step 448000 - time/iterations: 14
# 2026-05-05 03:24:06 [INFO] Step 448000 - time/fps: 183
# 2026-05-05 03:24:06 [INFO] Step 448000 - time/time_elapsed: 2443
# 2026-05-05 03:24:06 [INFO] Step 448000 - time/total_timesteps: 448000
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/learning_rate: 0.0003
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/entropy_loss: -2.151679417228699
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/policy_gradient_loss: -0.0024788674886338413
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/value_loss: 15.383975205492973
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/approx_kl: 0.014209959656000137
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/clip_fraction: 0.170996875
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/loss: 5.030425548553467
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/explained_variance: 0.8457483053207397
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/n_updates: 140
# 2026-05-05 03:27:02 [INFO] Step 480000 - train/clip_range: 0.2
# 2026-05-05 03:27:02 [INFO] Step 480000 - time/iterations: 15
# 2026-05-05 03:27:02 [INFO] Step 480000 - time/fps: 183
# 2026-05-05 03:27:02 [INFO] Step 480000 - time/time_elapsed: 2618
# 2026-05-05 03:27:02 [INFO] Step 480000 - time/total_timesteps: 480000
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/learning_rate: 0.0003
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/entropy_loss: -2.114636808156967
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/policy_gradient_loss: -0.0016473522186744958
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/value_loss: 17.018583973169328
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/approx_kl: 0.01562611199915409
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/clip_fraction: 0.16148125
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/loss: 9.199210166931152
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/explained_variance: 0.8321139812469482
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/n_updates: 150
# 2026-05-05 03:29:53 [INFO] Step 512000 - train/clip_range: 0.2
# 2026-05-05 03:29:53 [INFO] Step 512000 - time/iterations: 16
# 2026-05-05 03:29:53 [INFO] Step 512000 - time/fps: 183
# 2026-05-05 03:29:53 [INFO] Step 512000 - time/time_elapsed: 2790
# 2026-05-05 03:29:53 [INFO] Step 512000 - time/total_timesteps: 512000

# %%
from gymnasium.wrappers import RecordVideo

try:
    video_env = RecordVideo(env, video_folder="./", name_prefix=f"trained-{RUN_NAME}", episode_trigger=lambda x: True)
    obs, info = video_env.reset()
    done = False
    step_count = 0
    while not done:
        env.render()
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = video_env.step(action)
        step_count += 1
        if step_count % 1000 == 0:
            logger.info(f"Step: {step_count}")
        done = terminated or truncated
        if done:
            logger.info(f"Terminated: {terminated}")
            logger.info(f"Truncated: {truncated}")
except Exception as e:
    logger.error(e)
    raise e
finally:
    video_env.close()
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/wrappers/rendering.py:293: UserWarning: WARN: Overwriting existing videos at /content folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# 2026-05-05 03:30:30 [INFO] Terminated: True
# 2026-05-05 03:30:30 [INFO] Truncated: False
